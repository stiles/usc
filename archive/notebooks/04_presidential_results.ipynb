# %% [markdown]
# # 2020 presidential election results

# %% [markdown]
# ### Import Python tools

# %%
# !pip install nb_black
# %load_ext lab_black

# %%
import pandas as pd

# %% [markdown]
# ### Read the data

# %%
df = pd.read_json("../data/elections/election_results_2020.json")

# %%
df.columns
# Out:
# Index(['state_name', 'county_fips', 'county_name', 'votes_gop', 'votes_dem',
#        'total_votes'],
#       dtype='object')

# %% [markdown]
# ### Just the first five rows

# %%
df.head()
# Out:
#   state_name  county_fips     county_name  votes_gop  votes_dem  total_votes
# 0    Alabama         1001  Autauga County      19838       7503        27770
# 1    Alabama         1003  Baldwin County      83544      24578       109679
# 2    Alabama         1005  Barbour County       5622       4816        10518
# 3    Alabama         1007     Bibb County       7525       1986         9595
# 4    Alabama         1009   Blount County      24711       2640        27588

# %% [markdown]
# ### Let's change data types

# %%
df.dtypes
# Out:
# state_name     object
# county_fips     int64
# county_name    object
# votes_gop       int64
# votes_dem       int64
# total_votes     int64
# dtype: object

# %%
df["county_fips"] = df["county_fips"].astype(str)

# %% [markdown]
# ### Deal with four-digit FIPS codes

# %%
df["county_fips"] = df["county_fips"].str.zfill(5)

# %% [markdown]
# ### Basics about the dataset

# %%
df.describe().round()
# Out:
#        votes_gop  votes_dem  total_votes
# count     3152.0     3152.0       3152.0
# mean     23543.0    25782.0      50264.0
# std      54040.0    96930.0     149378.0
# min         60.0        4.0         66.0
# 25%       3662.0     1320.0       5415.0
# 50%       8123.0     3690.0      12336.0
# 75%      20509.0    11944.0      33304.0
# max    1145530.0  3028885.0    4263443.0

# %% [markdown]
# ### Look at a slim version of the data

# %%
df[["county_name", "total_votes"]].head()
# Out:
#       county_name  total_votes
# 0  Autauga County        27770
# 1  Baldwin County       109679
# 2  Barbour County        10518
# 3     Bibb County         9595
# 4   Blount County        27588

# %% [markdown]
# ### Let's change the county_name string

# %%
df["county_name"] = df["county_name"].str.replace(" County", "", regex=False)

# %% [markdown]
# ### Did it work? Subset the data

# %%
df[df["state_name"] == "Louisiana"].head()
# Out:
#      state_name county_fips        county_name  votes_gop  votes_dem  \
# 1123  Louisiana       22001      Acadia Parish      22596       5443
# 1124  Louisiana       22003       Allen Parish       7574       2108
# 1125  Louisiana       22005   Ascension Parish      40687      20399
# 1126  Louisiana       22007  Assumption Parish       7271       3833
# 1127  Louisiana       22009   Avoyelles Parish      12028       4979
#
#       total_votes
# 1123        28425
# 1124         9810
# 1125        62325
# 1126        11235
# 1127        17292

# %%
df["county_name"] = (
    df["county_name"]
    .str.replace(" County", "", regex=False)
    .str.replace(" Parish", "", regex=False)
)

# %% [markdown]
# ### Subset some more. Just large Texas counties?

# %%
df[(df["state_name"] == "Texas") & (df["total_votes"] > 500000)].head()
# Out:
#      state_name county_fips county_name  votes_gop  votes_dem  total_votes
# 2547      Texas       48029       Bexar     308618     448452       768952
# 2589      Texas       48113      Dallas     307076     598576       921638
# 2633      Texas       48201      Harris     700630     918193      1640818
# 2752      Texas       48439     Tarrant     409741     411567       834697
# 2759      Texas       48453      Travis     161337     435860       610349

# %% [markdown]
# ---

# %% [markdown]
# ### Calculate the margin for each party

# %%
df["margin_dem"] = df["votes_dem"] - df["votes_gop"]
df["margin_gop"] = df["votes_gop"] - df["votes_dem"]

# %%
df.head()
# Out:
#   state_name county_fips county_name  votes_gop  votes_dem  total_votes  \
# 0    Alabama       01001     Autauga      19838       7503        27770
# 1    Alabama       01003     Baldwin      83544      24578       109679
# 2    Alabama       01005     Barbour       5622       4816        10518
# 3    Alabama       01007        Bibb       7525       1986         9595
# 4    Alabama       01009      Blount      24711       2640        27588
#
#    margin_dem  margin_gop
# 0      -12335       12335
# 1      -58966       58966
# 2        -806         806
# 3       -5539        5539
# 4      -22071       22071

# %% [markdown]
# ### Calculate the vote share — or percentage — for each party

# %%
df["pct_dem"] = round((df["votes_dem"] / df["total_votes"]) * 100)
df["pct_gop"] = round((df["votes_gop"] / df["total_votes"]) * 100)

# %%
df["dem_diff"] = df["pct_dem"] - df["pct_gop"]
df["gop_diff"] = df["pct_gop"] - df["pct_dem"]

# %%
df.head()
# Out:
#   state_name county_fips county_name  votes_gop  votes_dem  total_votes  \
# 0    Alabama       01001     Autauga      19838       7503        27770
# 1    Alabama       01003     Baldwin      83544      24578       109679
# 2    Alabama       01005     Barbour       5622       4816        10518
# 3    Alabama       01007        Bibb       7525       1986         9595
# 4    Alabama       01009      Blount      24711       2640        27588
#
#    margin_dem  margin_gop  pct_dem  pct_gop  dem_diff  gop_diff
# 0      -12335       12335     27.0     71.0     -44.0      44.0
# 1      -58966       58966     22.0     76.0     -54.0      54.0
# 2        -806         806     46.0     53.0      -7.0       7.0
# 3       -5539        5539     21.0     78.0     -57.0      57.0
# 4      -22071       22071     10.0     90.0     -80.0      80.0

# %% [markdown]
# ### Which party won each county — the Python way?

# %%
def winner(row):
    if row["votes_dem"] > row["votes_gop"]:
        return "dem"
    elif row["votes_gop"] > row["votes_dem"]:
        return "gop"
    else:
        return "tie"

# %%
df["winner"] = df.apply(winner, axis=1)

# %% [markdown]
# ### Or, the Pandas way?

# %%
df["winner_nu"] = (
    df[["votes_gop", "votes_dem"]]
    .idxmax(axis=1)
    .str.replace("Mrs.", "Ms.", regex=False)
)

# %% [markdown]
# ### Did it work?

# %%
df.winner.value_counts()
# Out:
# gop    2595
# dem     557
# Name: winner, dtype: int64

# %%
df.winner_nu.value_counts("normalize")
# Out:
# votes_gop    0.823287
# votes_dem    0.176713
# Name: winner_nu, dtype: float64

# %% [markdown]
# ### We don't need that 'winner_nu' column

# %%
df.drop(["winner_nu"], axis=1, inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# ### Where was the Republicans' largest margin?

# %%
df.sort_values("margin_gop", ascending=False).head()
# Out:
#       state_name county_fips  county_name  votes_gop  votes_dem  total_votes  \
# 2702       Texas       48339   Montgomery     193382      74377       271451
# 2811        Utah       49049         Utah     192812      76033       284480
# 1798  New Jersey       34029        Ocean     217740     119456       342746
# 365      Florida       12071          Lee     233247     157695       393899
# 1174   Louisiana       22103  St. Tammany      99666      37746       140110
#
#       margin_dem  margin_gop  pct_dem  pct_gop  dem_diff  gop_diff winner
# 2702     -119005      119005     27.0     71.0     -44.0      44.0    gop
# 2811     -116779      116779     27.0     68.0     -41.0      41.0    gop
# 1798      -98284       98284     35.0     64.0     -29.0      29.0    gop
# 365       -75552       75552     40.0     59.0     -19.0      19.0    gop
# 1174      -61920       61920     27.0     71.0     -44.0      44.0    gop

# %% [markdown]
# ### Which counties were most Democratic?

# %%
df.sort_values("pct_dem", ascending="True").head()
# Out:
#      state_name county_fips county_name  votes_gop  votes_dem  total_votes  \
# 2729      Texas       48393     Roberts        529         17          550
# 2549      Texas       48033      Borden        397         16          416
# 1624    Montana       30033    Garfield        764         41          813
# 997      Kansas       20199     Wallace        762         44          817
# 2667      Texas       48269        King        151          8          159
#
#       margin_dem  margin_gop  pct_dem  pct_gop  dem_diff  gop_diff winner
# 2729        -512         512      3.0     96.0     -93.0      93.0    gop
# 2549        -381         381      4.0     95.0     -91.0      91.0    gop
# 1624        -723         723      5.0     94.0     -89.0      89.0    gop
# 997         -718         718      5.0     93.0     -88.0      88.0    gop
# 2667        -143         143      5.0     95.0     -90.0      90.0    gop

# %% [markdown]
# ### Which counties were most Republican?

# %%
df.sort_values("pct_dem", ascending="False").head()
# Out:
#      state_name county_fips county_name  votes_gop  votes_dem  total_votes  \
# 2729      Texas       48393     Roberts        529         17          550
# 2549      Texas       48033      Borden        397         16          416
# 1624    Montana       30033    Garfield        764         41          813
# 997      Kansas       20199     Wallace        762         44          817
# 2667      Texas       48269        King        151          8          159
#
#       margin_dem  margin_gop  pct_dem  pct_gop  dem_diff  gop_diff winner
# 2729        -512         512      3.0     96.0     -93.0      93.0    gop
# 2549        -381         381      4.0     95.0     -91.0      91.0    gop
# 1624        -723         723      5.0     94.0     -89.0      89.0    gop
# 997         -718         718      5.0     93.0     -88.0      88.0    gop
# 2667        -143         143      5.0     95.0     -90.0      90.0    gop

# %% [markdown]
# ### Which counties were most Democratic?

# %%
df[df["total_votes"] > 500000].sort_values("pct_dem", ascending=False).head()
# Out:
#         state_name county_fips   county_name  votes_gop  votes_dem  \
# 1868      New York       36061      New York      85185     603040
# 2304  Pennsylvania       42101  Philadelphia     132740     603790
# 197     California       06001       Alameda     136309     617659
# 1217      Maryland       24031    Montgomery     101222     419569
# 1861      New York       36047         Kings     202772     703310
#
#       total_votes  margin_dem  margin_gop  pct_dem  pct_gop  dem_diff  \
# 1868       695263      517855     -517855     87.0     12.0      75.0
# 2304       741377      471050     -471050     81.0     18.0      63.0
# 197        769864      481350     -481350     80.0     18.0      62.0
# 1217       533743      318347     -318347     79.0     19.0      60.0
# 1861       913690      500538     -500538     77.0     22.0      55.0
#
#       gop_diff winner
# 1868     -75.0    dem
# 2304     -63.0    dem
# 197      -62.0    dem
# 1217     -60.0    dem
# 1861     -55.0    dem

# %% [markdown]
# ---

# %% [markdown]
# ### Difference between counties won and votes won

# %%
df.winner.value_counts()
# Out:
# gop    2595
# dem     557
# Name: winner, dtype: int64

# %% [markdown]
# ### Aggregate by winner

# %%
df.votes_gop.sum()
# Out:
# 74208670

# %%
df.votes_dem.sum()
# Out:
# 81265196

# %%
df.groupby(["winner"]).agg({"total_votes": "mean"}).round(0).reset_index()
# Out:
#   winner  total_votes
# 0    dem     169433.0
# 1    gop      24685.0

# %% [markdown]
# ---

# %% [markdown]
# ### Aggregate by state

# %%
df.groupby(["state_name"]).agg(
    {"votes_gop": "sum", "votes_dem": "sum", "total_votes": "sum"}
).reset_index()
# Out:
#               state_name  votes_gop  votes_dem  total_votes
# 0                Alabama    1441168     849648      2323304
# 1                 Alaska     189892     153405       391346
# 2                Arizona    1661686    1672143      3387326
# 3               Arkansas     760647     423932      1219069
# 4             California    6005961   11109764     17495906
# 5               Colorado    1364607    1804352      3256953
# 6            Connecticut     715291    1080680      1824280
# 7               Delaware     200603     296268       504010
# 8   District of Columbia      18586     317323       344356
# 9                Florida    5668731    5297045     11067456
# 10               Georgia    2461854    2473633      4997716
# 11                Hawaii     196864     366130       574469
# 12                 Idaho     554119     287021       868106
# 13              Illinois    2446891    3471915      6038843
# 14               Indiana    1729852    1242495      3033198
# 15                  Iowa     897672     759061      1690871
# 16                Kansas     758100     558669      1349567
# 17              Kentucky    1326646     772474      2136768
# 18             Louisiana    1255776     856034      2148062
# 19                 Maine     359899     430473       813740
# 20              Maryland     976414    1985023      3037030
# 21         Massachusetts    1167202    2382202      3631402
# 22              Michigan    2649852    2804040      5539302
# 23             Minnesota    1484065    1717077      3277171
# 24           Mississippi     756764     539398      1315182
# 25              Missouri    1718736    1253014      3025962
# 26               Montana     343602     244786       605750
# 27              Nebraska     556846     374583       956379
# 28                Nevada     669890     703486      1405376
# 29         New Hampshire     365654     424921       804430
# 30            New Jersey    1883274    2608335      4564234
# 31            New Mexico     401894     501614       923965
# 32              New York    3250230    5244006      8613546
# 33        North Carolina    2758773    2684292      5524801
# 34          North Dakota     235595     114902       361819
# 35                  Ohio    3154834    2679165      5922202
# 36              Oklahoma    1020280     503890      1560699
# 37                Oregon     958448    1340383      2374321
# 38          Pennsylvania    3378263    3459923      6925255
# 39          Rhode Island     199837     306210       516383
# 40        South Carolina    1385103    1091541      2513329
# 41          South Dakota     261043     150471       422609
# 42             Tennessee    1852948    1143913      3054534
# 43                 Texas    5890347    5259126     11317911
# 44                  Utah     865140     560282      1488289
# 45               Vermont     112704     242820       367428
# 46              Virginia    1962430    2413568      4460524
# 47            Washington    1584651    2369612      4087631
# 48         West Virginia     545382     235984       794652
# 49             Wisconsin    1610065    1630673      3297352
# 50               Wyoming     193559      73491       276765

# %% [markdown]
# ### Assign the new dataframe to a variable called states

# %%
states = (
    df.groupby(["state_name"])
    .agg({"votes_gop": "sum", "votes_dem": "sum", "total_votes": "sum"})
    .reset_index()
)

# %% [markdown]
# ### Calculate vote share by state

# %%
states["pct_dem"] = round((states["votes_dem"] / states["total_votes"]) * 100)
states["pct_gop"] = round((states["votes_gop"] / states["total_votes"]) * 100)

# %%
states.head()
# Out:
#    state_name  votes_gop  votes_dem  total_votes  pct_dem  pct_gop
# 0     Alabama    1441168     849648      2323304     37.0     62.0
# 1      Alaska     189892     153405       391346     39.0     49.0
# 2     Arizona    1661686    1672143      3387326     49.0     49.0
# 3    Arkansas     760647     423932      1219069     35.0     62.0
# 4  California    6005961   11109764     17495906     63.0     34.0

# %% [markdown]
# ### And the winner is...

# %%
states["winner"] = (
    states[["votes_gop", "votes_dem"]]
    .idxmax(axis=1)
    .str.replace("votes_", "", regex=False)
)

# %%
states.head()
# Out:
#    state_name  votes_gop  votes_dem  total_votes  pct_dem  pct_gop winner
# 0     Alabama    1441168     849648      2323304     37.0     62.0    gop
# 1      Alaska     189892     153405       391346     39.0     49.0    gop
# 2     Arizona    1661686    1672143      3387326     49.0     49.0    dem
# 3    Arkansas     760647     423932      1219069     35.0     62.0    gop
# 4  California    6005961   11109764     17495906     63.0     34.0    dem

# %%
states["winner"].value_counts()
# Out:
# dem    26
# gop    25
# Name: winner, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ### Export the states

# %%
states.to_csv("../data/elections/states_election_results_2020.csv", index=False)

# %%
states.to_json(
    "../data/elections/states_election_results_2020.json", orient="records", indent=4
)

# %% [markdown]
# ### Counties

# %%
df.to_csv("../data/elections/counties_election_results_2020.csv", index=False)

# %%
df.to_json(
    "../data/elections/counties_election_results_2020.json", orient="records", indent=4
)
