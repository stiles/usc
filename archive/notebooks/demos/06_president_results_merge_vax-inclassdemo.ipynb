# %% [markdown]
# # Merge presidential election with vax rates

# %% [markdown]
# ### Import Python tools

# %%
# %load_ext lab_black
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %%
import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# ### Read elections data cleaned in 04 notebook

# %%
df = pd.read_json("../../data/elections/counties_election_results_2020.json")

# %% [markdown]
# ### Get vax data from CDC

# %%
# Cleaned up version (and most recent week) of this table
# vax_pct = pct fully vaccinated
# https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-County/8xkx-amqh

# %%
vax_counties = pd.read_json(
    "../../data/vaccinations/usa-vaccination-county-totals.json"
)

# %%
df["county_fips"] = df["county_fips"].astype(str)

# %% [markdown]
# ### Merge vax with election results

# %%
vax_counties.head()
# Out:
#     fips       county_name state_name  vax_pct
# 0  41061      Union County         OR     43.2
# 1  29093       Iron County         MO     33.9
# 2  38091     Steele County         ND     41.3
# 3  18085  Kosciusko County         IN     36.8
# 4  36075     Oswego County         NY     53.0

# %%
pd.merge(df, vax_counties[["fips", "vax_pct"]], left_on="county_fips", right_on="fips")
# Out:
#                 state_name county_fips           county_name  votes_gop  \
# 0                 Delaware       10001                  Kent      41009
# 1                 Delaware       10003            New Castle      88364
# 2                 Delaware       10005                Sussex      71230
# 3     District of Columbia       11001  District of Columbia      18586
# 4                  Florida       12001               Alachua      50972
# ...                    ...         ...                   ...        ...
# 2820               Wyoming       56037            Sweetwater      12229
# 2821               Wyoming       56039                 Teton       4341
# 2822               Wyoming       56041                 Uinta       7496
# 2823               Wyoming       56043              Washakie       3245
# 2824               Wyoming       56045                Weston       3107
#
#       votes_dem  total_votes  margin_dem  margin_gop  pct_dem  pct_gop  \
# 0         44552        87025        3543       -3543       51       47
# 1        195034       287633      106670     -106670       68       31
# 2         56682       129352      -14548       14548       44       55
# 3        317323       344356      298737     -298737       92        5
# 4         89704       142604       38732      -38732       63       36
# ...         ...          ...         ...         ...      ...      ...
# 2820       3823        16603       -8406        8406       23       74
# 2821       9848        14677        5507       -5507       67       30
# 2822       1591         9402       -5905        5905       17       80
# 2823        651         4012       -2594        2594       16       81
# 2824        360         3542       -2747        2747       10       88
#
#       dem_diff  gop_diff winner   fips  vax_pct
# 0            4        -4    dem  10001     46.5
# 1           37       -37    dem  10003     58.6
# 2          -11        11    gop  10005     58.7
# 3           87       -87    dem  11001     58.1
# 4           27       -27    dem  12001     59.1
# ...        ...       ...    ...    ...      ...
# 2820       -51        51    gop  56037     37.9
# 2821        37       -37    dem  56039     79.9
# 2822       -63        63    gop  56041     40.6
# 2823       -65        65    gop  56043     35.9
# 2824       -78        78    gop  56045     31.3
#
# [2825 rows x 15 columns]
