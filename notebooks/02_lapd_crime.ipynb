# %% [markdown]
# # LAPD crime data

# %% [markdown]
# ### Import Python tools

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---

# %%
df = pd.read_csv('../../usc/data/lapd/lapd_crimes_2010_present_usc_area.csv', dtype={'premises_code':str, 'crime_code':str})

# %%
df.head()
# Out:
#    record_id date_reported date_occurred  time_occurred  division  \
# 0  200305577    2020-01-27    2020-01-25           2300       3.0
# 1  200300514    2020-01-05    2020-01-05           1446       3.0
# 2  200300521    2020-01-10    2020-01-09            830       3.0
# 3  200304073    2020-01-01    2020-01-01           1300       3.0
# 4  200304130    2020-01-02    2020-01-01           2345       3.0
#
#   division_name  reporting_district  part_type crime_code  \
# 0     Southwest                 338          1        510
# 1     Southwest                 378          2        946
# 2     Southwest                 379          2        654
# 3     Southwest                 357          2        626
# 4     Southwest                 328          1        220
#
#                   crime_code_description  ...  year  quarter day month  \
# 0                       Vehicle - stolen  ...  2020        1  25     1
# 1              Other miscellaneous crime  ...  2020        1   5     1
# ...

# %%
df.iloc[20]
# Out:
# record_id                                                     200304501
# date_reported                                                2020-01-09
# date_occurred                                                2020-01-08
# time_occurred                                                      1930
# division                                                            3.0
# division_name                                                 Southwest
# reporting_district                                                  379
# part_type                                                             2
# crime_code                                                          930
# crime_code_description           Criminal threats - no weapon displayed
# modus_operandi_code                                      1810 0443 0432
# victim_age                                                           30
# victim_sex                                                       female
# ...

# %% [markdown]
# #### Just crimes involving campus and student victims

# %%
df[(df['premises_code'] == '722') \
   & (df['modus_operandi_code'].str.contains('1251')) \
  & (df['crime_code'] == '480')]
# Out:
#        record_id date_reported date_occurred  time_occurred  division  \
# 60     200305114    2020-01-20    2020-01-20           1000       3.0
# 128    200306010    2020-02-03    2020-02-03           1740       3.0
# 220    200307016    2020-02-18    2020-02-17           1200       3.0
# 236    200307015    2020-02-18    2020-02-13           1900       3.0
# 237    200307083    2020-02-20    2020-02-17           2200       3.0
# ...          ...           ...           ...            ...       ...
# 20642  190311843    2019-04-29    2019-04-26           1530       NaN
# 20658  190325068    2019-11-21    2019-11-19           1700       NaN
# 20674  190324923    2019-11-19    2019-10-15            830       NaN
# 20686  190320537    2019-09-11    2019-09-11           1830       NaN
# 20691  190309120    2019-03-20    2019-03-08            900       NaN
#
#       division_name  reporting_district  part_type crime_code  \
# 60        Southwest                 358          1        480
# ...

# %%
students_campus_bikes = df[(df['premises_code'] == '722') \
   & (df['modus_operandi_code'].str.contains('1251')) \
  & (df['crime_code'] == '480')]

# %%
len(students_campus_bikes)
# Out:
# 587

# %%
students_campus_bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 587 entries, 60 to 20691
# Data columns (total 38 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   record_id                587 non-null    int64
#  1   date_reported            587 non-null    object
#  2   date_occurred            587 non-null    object
#  3   time_occurred            587 non-null    int64
#  4   division                 21 non-null     float64
#  5   division_name            587 non-null    object
#  6   reporting_district       587 non-null    int64
#  7   part_type                587 non-null    int64
#  8   crime_code               587 non-null    object
#  9   crime_code_description   587 non-null    object
#  10  modus_operandi_code      587 non-null    object
#  11  victim_age               587 non-null    int64
#  12  victim_sex               587 non-null    object
#  13  victim_descent           587 non-null    object
# ...

# %% [markdown]
# ---
