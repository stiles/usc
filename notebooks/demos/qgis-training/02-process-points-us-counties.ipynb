# %% [markdown]
# # Presidential vote by counties

# %% [markdown]
# ### Import Python tools

# %%
# %load_ext lab_black

# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ---

# %% [markdown]
# ### Read counties geo file

# %% [markdown]
# ### What's it look like?

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Convert the projection to North American Lambert Conformal Conic

# %% [markdown]
# ### How has the shape changed?

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Get the point at the center of the county for plotting symbols

# %% [markdown]
# ### Drop the old geo field

# %% [markdown]
# ### Convert the points into our new geo field

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Export the results. Weeeeeeeeee.
