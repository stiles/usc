# %% [markdown]
# # Week 6: Merging data with Pandas, Part 1
# What's the relationship between vaccination rates and votes in the recall election [using the `merge()` method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html)

# %% [markdown]
# #### Load our Python tools

# %%
# %load_ext lab_black

# %%
import pandas as pd
import altair as alt

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 1000
pd.options.display.max_colwidth = None

# %% [markdown]
# ---

# %% [markdown]
# ### Vax percentage

# %% [markdown]
# #### LA Times [coronavirus repo](https://github.com/datadesk/california-coronavirus-data)

# %%
vax_url = "https://raw.githubusercontent.com/datadesk/california-coronavirus-data/master/cdph-vaccination-county-totals.csv"

# %% [markdown]
# #### Read weekly vaccination totals by county data (data types can be defined here)

# %%
vax_df = pd.read_csv(vax_url, dtype={"fips": str})

# %% [markdown]
# #### How many weeks is this (don't forget to sort)?

# %%
vax_df.head()
# Out:
#          date     county fips  population  doses_administered  \
# 0  2022-02-16    Alameda  001   1643700.0             3489536
# 1  2022-02-16     Alpine  003      1148.0                1864
# 2  2022-02-16     Amador  005     37829.0               53948
# 3  2022-02-16      Butte  007    227075.0              287105
# 4  2022-02-16  Calaveras  009     45235.0               63074
#
#    new_doses_administered  pfizer_doses  new_pfizer_doses  moderna_doses  \
# 0                    2748     2129666.0              1576      1061910.0
# 1                       0          73.0                 0         1769.0
# 2                      23       15772.0                12        35722.0
# 3                     209      141253.0               114       130049.0
# 4                      19       26888.0                10        33873.0
#
#    new_moderna_doses  jj_doses  new_jj_doses  partially_vaccinated  \
# 0                574  133454.0            32              107927.0
# 1                  0       9.0             0                 138.0
# 2                  8    1910.0             0                3930.0
# 3                 80   10199.0             2               10724.0
# 4                  9    1815.0             0                4403.0
#
#    new_partially_vaccinated  at_least_one_dose  new_at_least_one_dose  \
# 0                       438          1447947.0                    447
# 1                         0              856.0                      0
# 2                         7            24466.0                      7
# 3                        18           124934.0                     18
# 4                         4            28497.0                      4
#
#    fully_vaccinated  new_fully_vaccinated  partially_vaccinated_percent  \
# 0         1340020.0                   729                      0.065661
# 1             718.0                     0                      0.120209
# 2           20536.0                     2                      0.103889
# 3          114210.0                    33                      0.047227
# 4           24094.0                     5                      0.097336
#
#    at_least_one_dose_percent  fully_vaccinated_percent
# 0                   0.880907                  0.815246
# 1                   0.745645                  0.625436
# 2                   0.646752                  0.542864
# 3                   0.550188                  0.502962
# 4                   0.629977                  0.532641

# %%
vax_df["date"].min()
# Out:
# '2020-01-05'

# %%
vax_df["date"].max()
# Out:
# '2022-02-16'

# %% [markdown]
# #### Select the most recent week

# %%
most_recent = vax_df[vax_df["date"] == vax_df["date"].max()]

# %%
len(most_recent)
# Out:
# 58

# %% [markdown]
# #### Get only the columns we need

# %%
most_recent.head()
# Out:
#          date     county fips  population  doses_administered  \
# 0  2022-02-16    Alameda  001   1643700.0             3489536
# 1  2022-02-16     Alpine  003      1148.0                1864
# 2  2022-02-16     Amador  005     37829.0               53948
# 3  2022-02-16      Butte  007    227075.0              287105
# 4  2022-02-16  Calaveras  009     45235.0               63074
#
#    new_doses_administered  pfizer_doses  new_pfizer_doses  moderna_doses  \
# 0                    2748     2129666.0              1576      1061910.0
# 1                       0          73.0                 0         1769.0
# 2                      23       15772.0                12        35722.0
# 3                     209      141253.0               114       130049.0
# 4                      19       26888.0                10        33873.0
#
#    new_moderna_doses  jj_doses  new_jj_doses  partially_vaccinated  \
# 0                574  133454.0            32              107927.0
# 1                  0       9.0             0                 138.0
# 2                  8    1910.0             0                3930.0
# 3                 80   10199.0             2               10724.0
# 4                  9    1815.0             0                4403.0
#
#    new_partially_vaccinated  at_least_one_dose  new_at_least_one_dose  \
# 0                       438          1447947.0                    447
# 1                         0              856.0                      0
# 2                         7            24466.0                      7
# 3                        18           124934.0                     18
# 4                         4            28497.0                      4
#
#    fully_vaccinated  new_fully_vaccinated  partially_vaccinated_percent  \
# 0         1340020.0                   729                      0.065661
# 1             718.0                     0                      0.120209
# 2           20536.0                     2                      0.103889
# 3          114210.0                    33                      0.047227
# 4           24094.0                     5                      0.097336
#
#    at_least_one_dose_percent  fully_vaccinated_percent
# 0                   0.880907                  0.815246
# 1                   0.745645                  0.625436
# 2                   0.646752                  0.542864
# 3                   0.550188                  0.502962
# 4                   0.629977                  0.532641

# %%
vax_slim = most_recent[["county", "fips", "fully_vaccinated", "population"]]

# %%
vax_slim.head()
# Out:
#       county fips  fully_vaccinated  population
# 0    Alameda  001         1340020.0   1643700.0
# 1     Alpine  003             718.0      1148.0
# 2     Amador  005           20536.0     37829.0
# 3      Butte  007          114210.0    227075.0
# 4  Calaveras  009           24094.0     45235.0

# %% [markdown]
# ---

# %% [markdown]
# ### Recall vote

# %% [markdown]
# #### Read the county-level election results

# %%
recall_df = pd.read_json(
    "../../data/raw/gov_race_change_counties.json", dtype={"fips": str}
)

# %%
recall_df.head()
# Out:
#       county fips  dem_2018  dem_2021  rep_2018  rep_2021  votes_2018  \
# 0    Alameda  001    462558    287014    111677     60716      574235
# 1     Alpine  003       386       340       229       218         615
# 2     Amador  005      6237      6411     11356     10971       17593
# 3      Butte  007     41500     31774     47226     35182       88726
# 4  Calaveras  009      7765      7106     13845     11450       21610
#
#    votes_2021  d_pct_18  d_pct_21  r_pct_18  r_pct_21  d_change  r_change  \
# 0      347730      80.6      82.5      19.4      17.5       1.9      -1.9
# 1         558      62.8      60.9      37.2      39.1      -1.9       1.9
# 2       17382      35.5      36.9      64.5      63.1       1.4      -1.4
# 3       66956      46.8      47.5      53.2      52.5       0.7      -0.7
# 4       18556      35.9      38.3      64.1      61.7       2.4      -2.4
#
#   leader_2021 leader_2018
# 0           D           D
# 1           D           D
# 2           R           R
# 3           R           R
# 4           R           R

# %% [markdown]
# #### Rename columns

# %%
recall_df.rename(
    columns={
        "d_pct_21": "no_percent",
        "r_pct_21": "yes_percent",
        "leader_2021": "winner_2021",
    },
    inplace=True,
)

# %% [markdown]
# #### What's that look like?

# %%
recall_df.head()
# Out:
#       county fips  dem_2018  dem_2021  rep_2018  rep_2021  votes_2018  \
# 0    Alameda  001    462558    287014    111677     60716      574235
# 1     Alpine  003       386       340       229       218         615
# 2     Amador  005      6237      6411     11356     10971       17593
# 3      Butte  007     41500     31774     47226     35182       88726
# 4  Calaveras  009      7765      7106     13845     11450       21610
#
#    votes_2021  d_pct_18  no_percent  r_pct_18  yes_percent  d_change  \
# 0      347730      80.6        82.5      19.4         17.5       1.9
# 1         558      62.8        60.9      37.2         39.1      -1.9
# 2       17382      35.5        36.9      64.5         63.1       1.4
# 3       66956      46.8        47.5      53.2         52.5       0.7
# 4       18556      35.9        38.3      64.1         61.7       2.4
#
#    r_change winner_2021 leader_2018
# 0      -1.9           D           D
# 1       1.9           D           D
# 2      -1.4           R           R
# 3      -0.7           R           R
# 4      -2.4           R           R

# %% [markdown]
# #### Which county was most against the recall?

# %%
recall_df.sort_values("no_percent", ascending=False)
# Out:
#              county fips  dem_2018  dem_2021  rep_2018  rep_2021  votes_2018  \
# 37    San Francisco  075    312181    231861     49181     35571      361362
# 20            Marin  041    103671     79616     26750     14873      130421
# 0           Alameda  001    462558    287014    111677     60716      574235
# 43       Santa Cruz  087     91523     60654     27665     15004      119188
# 40        San Mateo  081    213282    174757     70242     46076      283524
# 48           Sonoma  097    152040    112264     58338     31939      210378
# 42      Santa Clara  085    438758    367471    175791    116687      614549
# 6      Contra Costa  013    283805    252879    132345     92905      416150
# 56             Yolo  113     49759     37591     23611     15052       73370
# 26         Monterey  053     76648     59525     39516     24456      116164
# 18      Los Angeles  037   2114699   1598140    826402    657584     2941101
# 27             Napa  055     36513     26526     19834     11098       56347
# 22        Mendocino  045     22152     13015     11255      5686       33407
# 11         Humboldt  023     33455     24669     18418     12772       51873
# 41    Santa Barbara  083     93841     68185     61300     36713      155141
# 47           Solano  095     89694     76235     56627     42336      146321
# 33       Sacramento  067    302696    196291    212010    110502      514706
# 12         Imperial  025     20573      8830     12785      5572       33358
# 1            Alpine  003       386       340       229       218         615
# 16             Lake  033     10869      5605     10280      3728       21149
# 55          Ventura  111    171729    140083    137393     95203      309122
# 34       San Benito  069     11274      9295      8815      6407       20089
# 36        San Diego  073    658346    512975    499532    362449     1157878
# 39  San Luis Obispo  079     65117     32903     61137     23306      126254
# 28           Nevada  057     27985     23519     24882     17277       52867
# 25             Mono  051      2706      2074      2147      1540        4853
# 38      San Joaquin  077    101474     66752     92966     52479      194440
# 29           Orange  059    543047    464164    539951    418362     1082998
# 32        Riverside  065    319845    262850    322243    238526      642088
# 35   San Bernardino  071    276874    198709    260379    183168      537253
# 23           Merced  047     30783     18168     28424     18130       59207
# 9            Fresno  019    124332     89502    128974     90181      253306
# 13             Inyo  027      3244      2431      4018      2514        7262
# 30           Placer  061     72270     56455    103157     59059      175427
# 49       Stanislaus  099     77220     50929     79751     54507      156971
# 3             Butte  007     41500     31774     47226     35182       88726
# 52          Trinity  105      2250      1747      3075      2079        5325
# 8         El Dorado  017     36297     30715     53140     37723       89437
# 7         Del Norte  015      3441      3038      4887      4198        8328
# 14             Kern  029     83507     37262    119870     51725      203377
# 53           Tulare  107     42702     30597     57012     43363       99714
# 46         Siskiyou  093      7218      5811     10946      8257       18164
# 19           Madera  039     15037     12757     23488     18271       38525
# 50           Sutter  101     11122      7664     18953     11114       30075
# 21         Mariposa  043      3183      3086      5043      4572        8226
# 54         Tuolumne  109      9294      9267     14580     14148       23874
# 57             Yuba  115      6903      5208     12293      8084       19196
# 4         Calaveras  009      7765      7106     13845     11450       21610
# 45           Sierra  091       599       555      1068       903        1667
# 15            Kings  031     12275      8799     17976     14828       30251
# 5            Colusa  011      1999      1436      3764      2434        5763
# 31           Plumas  063      3433      3008      5807      5106        9240
# 2            Amador  005      6237      6411     11356     10971       17593
# 44           Shasta  089     20256     15726     49825     30932       70081
# 10            Glenn  021      2424      1941      5908      4393        8332
# 51           Tehama  103      5756      2035     15137      5721       20893
# 24            Modoc  049       820       706      2628      2505        3448
# 17           Lassen  035      2043      1357      6973      6590        9016
#
#     votes_2021  d_pct_18  no_percent  r_pct_18  yes_percent  d_change  \
# 37      267432      86.4        86.7      13.6         13.3       0.3
# 20       94489      79.5        84.3      20.5         15.7       4.8
# 0       347730      80.6        82.5      19.4         17.5       1.9
# 43       75658      76.8        80.2      23.2         19.8       3.4
# 40      220833      75.2        79.1      24.8         20.9       3.9
# 48      144203      72.3        77.9      27.7         22.1       5.6
# 42      484158      71.4        75.9      28.6         24.1       4.5
# 6       345784      68.2        73.1      31.8         26.9       4.9
# 56       52643      67.8        71.4      32.2         28.6       3.6
# 26       83981      66.0        70.9      34.0         29.1       4.9
# 18     2255724      71.9        70.8      28.1         29.2      -1.1
# 27       37624      64.8        70.5      35.2         29.5       5.7
# 22       18701      66.3        69.6      33.7         30.4       3.3
# 11       37441      64.5        65.9      35.5         34.1       1.4
# 41      104898      60.5        65.0      39.5         35.0       4.5
# 47      118571      61.3        64.3      38.7         35.7       3.0
# 33      306793      58.8        64.0      41.2         36.0       5.2
# 12       14402      61.7        61.3      38.3         38.7      -0.4
# 1          558      62.8        60.9      37.2         39.1      -1.9
# 16        9333      51.4        60.1      48.6         39.9       8.7
# 55      235286      55.6        59.5      44.4         40.5       3.9
# 34       15702      56.1        59.2      43.9         40.8       3.1
# 36      875424      56.9        58.6      43.1         41.4       1.7
# 39       56209      51.6        58.5      48.4         41.5       6.9
# 28       40796      52.9        57.7      47.1         42.3       4.8
# 25        3614      55.8        57.4      44.2         42.6       1.6
# 38      119231      52.2        56.0      47.8         44.0       3.8
# 29      882526      50.1        52.6      49.9         47.4       2.5
# 32      501376      49.8        52.4      50.2         47.6       2.6
# 35      381877      51.5        52.0      48.5         48.0       0.5
# 23       36298      52.0        50.1      48.0         49.9      -1.9
# 9       179683      49.1        49.8      50.9         50.2       0.7
# 13        4945      44.7        49.2      55.3         50.8       4.5
# 30      115514      41.2        48.9      58.8         51.1       7.7
# 49      105436      49.2        48.3      50.8         51.7      -0.9
# 3        66956      46.8        47.5      53.2         52.5       0.7
# 52        3826      42.3        45.7      57.7         54.3       3.4
# 8        68438      40.6        44.9      59.4         55.1       4.3
# 7         7236      41.3        42.0      58.7         58.0       0.7
# 14       88987      41.1        41.9      58.9         58.1       0.8
# 53       73960      42.8        41.4      57.2         58.6      -1.4
# 46       14068      39.7        41.3      60.3         58.7       1.6
# 19       31028      39.0        41.1      61.0         58.9       2.1
# 50       18778      37.0        40.8      63.0         59.2       3.8
# 21        7658      38.7        40.3      61.3         59.7       1.6
# 54       23415      38.9        39.6      61.1         60.4       0.7
# 57       13292      36.0        39.2      64.0         60.8       3.2
# 4        18556      35.9        38.3      64.1         61.7       2.4
# 45        1458      35.9        38.1      64.1         61.9       2.2
# 15       23627      40.6        37.2      59.4         62.8      -3.4
# 5         3870      34.7        37.1      65.3         62.9       2.4
# 31        8114      37.2        37.1      62.8         62.9      -0.1
# 2        17382      35.5        36.9      64.5         63.1       1.4
# 44       46658      28.9        33.7      71.1         66.3       4.8
# 10        6334      29.1        30.6      70.9         69.4       1.5
# 51        7756      27.5        26.2      72.5         73.8      -1.3
# 24        3211      23.8        22.0      76.2         78.0      -1.8
# 17        7947      22.7        17.1      77.3         82.9      -5.6
#
#     r_change winner_2021 leader_2018
# 37      -0.3           D           D
# 20      -4.8           D           D
# 0       -1.9           D           D
# 43      -3.4           D           D
# 40      -3.9           D           D
# 48      -5.6           D           D
# 42      -4.5           D           D
# 6       -4.9           D           D
# 56      -3.6           D           D
# 26      -4.9           D           D
# 18       1.1           D           D
# 27      -5.7           D           D
# 22      -3.3           D           D
# 11      -1.4           D           D
# 41      -4.5           D           D
# 47      -3.0           D           D
# 33      -5.2           D           D
# 12       0.4           D           D
# 1        1.9           D           D
# 16      -8.7           D           D
# 55      -3.9           D           D
# 34      -3.1           D           D
# 36      -1.7           D           D
# 39      -6.9           D           D
# 28      -4.8           D           D
# 25      -1.6           D           D
# 38      -3.8           D           D
# 29      -2.5           D           D
# 32      -2.6           D           R
# 35      -0.5           D           D
# 23       1.9           D           D
# 9       -0.7           R           R
# 13      -4.5           R           R
# 30      -7.7           R           R
# 49       0.9           R           R
# 3       -0.7           R           R
# 52      -3.4           R           R
# 8       -4.3           R           R
# 7       -0.7           R           R
# 14      -0.8           R           R
# 53       1.4           R           R
# 46      -1.6           R           R
# 19      -2.1           R           R
# 50      -3.8           R           R
# 21      -1.6           R           R
# 54      -0.7           R           R
# 57      -3.2           R           R
# 4       -2.4           R           R
# 45      -2.2           R           R
# 15       3.4           R           R
# 5       -2.4           R           R
# 31       0.1           R           R
# 2       -1.4           R           R
# 44      -4.8           R           R
# 10      -1.5           R           R
# 51       1.3           R           R
# 24       1.8           R           R
# 17       5.6           R           R

# %%
recall_df.sort_values("yes_percent", ascending=False).head()
# Out:
#     county fips  dem_2018  dem_2021  rep_2018  rep_2021  votes_2018  \
# 17  Lassen  035      2043      1357      6973      6590        9016
# 24   Modoc  049       820       706      2628      2505        3448
# 51  Tehama  103      5756      2035     15137      5721       20893
# 10   Glenn  021      2424      1941      5908      4393        8332
# 44  Shasta  089     20256     15726     49825     30932       70081
#
#     votes_2021  d_pct_18  no_percent  r_pct_18  yes_percent  d_change  \
# 17        7947      22.7        17.1      77.3         82.9      -5.6
# 24        3211      23.8        22.0      76.2         78.0      -1.8
# 51        7756      27.5        26.2      72.5         73.8      -1.3
# 10        6334      29.1        30.6      70.9         69.4       1.5
# 44       46658      28.9        33.7      71.1         66.3       4.8
#
#     r_change winner_2021 leader_2018
# 17       5.6           R           R
# 24       1.8           R           R
# 51       1.3           R           R
# 10      -1.5           R           R
# 44      -4.8           R           R

# %%
recall_df[recall_df["yes_percent"] == recall_df["yes_percent"].max()]
# Out:
#     county fips  dem_2018  dem_2021  rep_2018  rep_2021  votes_2018  \
# 17  Lassen  035      2043      1357      6973      6590        9016
#
#     votes_2021  d_pct_18  no_percent  r_pct_18  yes_percent  d_change  \
# 17        7947      22.7        17.1      77.3         82.9      -5.6
#
#     r_change winner_2021 leader_2018
# 17       5.6           R           R

# %% [markdown]
# #### For it?

# %% [markdown]
# #### Get only the columns we need

# %%
recall_df_slim = recall_df[
    ["county", "fips", "no_percent", "yes_percent", "winner_2021"]
]

# %%
recall_df_slim.head()
# Out:
#       county fips  no_percent  yes_percent winner_2021
# 0    Alameda  001        82.5         17.5           D
# 1     Alpine  003        60.9         39.1           D
# 2     Amador  005        36.9         63.1           R
# 3      Butte  007        47.5         52.5           R
# 4  Calaveras  009        38.3         61.7           R

# %% [markdown]
# ---

# %% [markdown]
# ## Merge the vax data with the election results

# %% [markdown]
# #### Use the `merge()` method

# %%
merge_df = pd.merge(vax_slim, recall_df_slim, on="fips")

# %%
merge_df.head()
# Out:
#     county_x fips  fully_vaccinated  population   county_y  no_percent  \
# 0    Alameda  001         1340020.0   1643700.0    Alameda        82.5
# 1     Alpine  003             718.0      1148.0     Alpine        60.9
# 2     Amador  005           20536.0     37829.0     Amador        36.9
# 3      Butte  007          114210.0    227075.0      Butte        47.5
# 4  Calaveras  009           24094.0     45235.0  Calaveras        38.3
#
#    yes_percent winner_2021
# 0         17.5           D
# 1         39.1           D
# 2         63.1           R
# 3         52.5           R
# 4         61.7           R

# %%
merge_df.rename(
    columns={"county_x": "county", "county_y": "county_other"}, inplace=True
)

# %% [markdown]
# #### Correlation?

# %% [markdown]
# ---

# %%
# domain = ["R", "D"]
# range_ = ["#d94f54", "#5789b8"]

# alt.Chart(merged).mark_circle(size=100).encode(
#     x=alt.X(
#         "no_percent",
#         scale=alt.Scale(domain=[10, 100]),
#         axis=alt.Axis(tickCount=6, title="No percentage"),
#     ),
#     y=alt.Y(
#         "fully_vaccinated_percent",
#         scale=alt.Scale(domain=[0.2, 1]),
#         axis=alt.Axis(tickCount=6, title="One dose percentage", format="%"),
#     ),
#     #     size="population",
#     color=alt.Color("winner_2021", scale=alt.Scale(domain=domain, range=range_)),
#     #     tooltip=["county", "population"],
# ).properties(width=500, height=500)
