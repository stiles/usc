# %% [markdown]
# 1. Load Pandas:

# %%
import pandas as pd

# %% [markdown]
# 2. Read a dataset:

# %%
df_csv = pd.read_csv('C:/Users/William Xu/Documents/GitHub/Jour-561_0203/data_w6/covid_world_weekly_trend.csv')

# %%
df_csv.head()
# Out:
#   Country, Other  Cases in the last 7 days  Cases in the preceding 7 days  \
# 0    Afghanistan                      1365                           4003
# 1        Albania                      2066                           3429
# 2        Algeria                      2036                           3687
# 3        Andorra                       312                            469
# 4         Angola                       126                            123
#
#    Weekly Case % Change  Cases in the last 7 days/1M pop  \
# 0                 -66.0                             34.0
# 1                 -40.0                            719.0
# 2                 -45.0                             45.0
# 3                 -33.0                           4027.0
# 4                   2.0                              4.0
#
#    Deaths in the last 7 days  Deaths in the preceding 7 days  \
# 0                         48                              59
# ...

# %% [markdown]
# 3. Explore the dataset using len()/sort_values()/value_counts()/describe()

# %%
len(df_csv)
# Out:
# 215

# %%
df_csv.sort_values('Cases in the last 7 days', ascending=False).head()
# Out:
#     Country, Other  Cases in the last 7 days  Cases in the preceding 7 days  \
# 159         Russia                   1208791                        1331942
# 75         Germany                   1199728                        1315787
# 26          Brazil                    709460                         935994
# 162       S. Korea                    652938                         360283
# 200         Turkey                    604558                         649938
#
#      Weekly Case % Change  Cases in the last 7 days/1M pop  \
# 159                  -9.0                           8277.0
# 75                   -9.0                          14245.0
# 26                  -24.0                           3299.0
# 162                  81.0                          12718.0
# 200                  -7.0                           7044.0
#
#      Deaths in the last 7 days  Deaths in the preceding 7 days  \
# 159                       5304                            4908
# ...

# %%
df_csv.sort_values('Deaths in the last 7 days', ascending=False).head(10)
# Out:
#     Country, Other  Cases in the last 7 days  Cases in the preceding 7 days  \
# 204            USA                    574030                        1104395
# 26          Brazil                    709460                         935994
# 159         Russia                   1208791                        1331942
# 91           India                    158986                         353332
# 127         Mexico                    120719                         141181
# 200         Turkey                    604558                         649938
# 98           Italy                    359837                         470719
# 182          Spain                    185094                         277435
# 69          France                    568722                         930930
# 155         Poland                    147684                         227578
#
#      Weekly Case % Change  Cases in the last 7 days/1M pop  \
# 204                 -48.0                           1718.0
# ...

# %%
df_csv.value_counts('Deaths in the last 7 days/1M pop')
# Out:
# Deaths in the last 7 days/1M pop
# 0.0      38
# 1.0      11
# 4.0       8
# 6.0       7
# 0.1       7
#          ..
# 11.0      1
# 13.0      1
# 24.0      1
# 20.0      1
# 121.0     1
# Length: 67, dtype: int64

# %%
df_csv.value_counts('Deaths in the last 7 days/1M pop')
# Out:
# Deaths in the last 7 days/1M pop
# 0.0      38
# 1.0      11
# 4.0       8
# 6.0       7
# 0.1       7
#          ..
# 11.0      1
# 13.0      1
# 24.0      1
# 20.0      1
# 121.0     1
# Length: 67, dtype: int64

# %%
df_slim = df_csv.drop(['Population'], axis = 1)
df_slim
# Out:
#     Country, Other  Cases in the last 7 days  Cases in the preceding 7 days  \
# 0      Afghanistan                      1365                           4003
# 1          Albania                      2066                           3429
# 2          Algeria                      2036                           3687
# 3          Andorra                       312                            469
# 4           Angola                       126                            123
# ..             ...                       ...                            ...
# 210      Venezuela                      4795                           9000
# 211        Vietnam                    281944                         182357
# 212          Yemen                        62                            125
# 213         Zambia                      1685                           2262
# 214       Zimbabwe                      1968                           1000
#
# ...

# %%
df_slim.describe().round()
# Out:
#        Cases in the last 7 days  Cases in the preceding 7 days  \
# count                     215.0                          215.0
# mean                    57526.0                        71599.0
# std                    161268.0                       195128.0
# min                         0.0                            0.0
# 25%                       157.0                          225.0
# 50%                      2264.0                         3687.0
# 75%                     26642.0                        40003.0
# max                   1208791.0                      1331942.0
#
#        Weekly Case % Change  Cases in the last 7 days/1M pop  \
# count                 215.0                            215.0
# mean                  543.0                           4676.0
# std                  7275.0                           8484.0
# min                  -100.0                              0.0
# 25%                   -45.0                             50.0
# ...

# %%
df_csv['Cases in the last 7 days'].max()
# Out:
# 1208791

# %% [markdown]
# 4.Subset the dataframe

# %%
populous_df1 = df_csv[df_csv['Population'] > 100000000]
populous_df1
# Out:
#     Country, Other  Cases in the last 7 days  Cases in the preceding 7 days  \
# 15      Bangladesh                     20886                          43455
# 26          Brazil                    709460                         935994
# 42           China                       837                            595
# 59           Egypt                     14379                          15158
# 65        Ethiopia                       804                            898
# 91           India                    158986                         353332
# 92       Indonesia                    387644                         301678
# 101          Japan                    572555                         611609
# 127         Mexico                    120719                         141181
# 143        Nigeria                       202                            311
# 147       Pakistan                     15319                          23250
# ...

# %%
df_slim1 = populous_df1 [["Country, Other", "Cases in the last 7 days", "Deaths in the last 7 days", "Population"]]

# %%
df_slim1.head(10)
# Out:
#     Country, Other  Cases in the last 7 days  Deaths in the last 7 days  \
# 15      Bangladesh                     20886                        136
# 26          Brazil                    709460                       5782
# 42           China                       837                          0
# 59           Egypt                     14379                        397
# 65        Ethiopia                       804                         14
# 91           India                    158986                       2983
# 92       Indonesia                    387644                       1220
# 101          Japan                    572555                       1462
# 127         Mexico                    120719                       2869
# 143        Nigeria                       202                          1
#
#      Population
# 15    167377842
# 26    215035499
# 42   1448432924
# 59    105495301
# 65    119625184
# 91   1402235728
# 92    278262700
# 101   125841851
# 127   131152303
# ...

# %%
populous_df2 = df_csv[df_csv['Population'] < 1000000]
populous_df2.head()
# Out:
#          Country, Other  Cases in the last 7 days  \
# 3               Andorra                       312
# 5              Anguilla                         9
# 6   Antigua and Barbuda                        77
# 9                 Aruba                       105
# 13              Bahamas                       118
#
#     Cases in the preceding 7 days  Weekly Case % Change  \
# 3                             469                 -33.0
# 5                              61                 -85.0
# 6                             478                 -84.0
# 9                             185                 -43.0
# 13                            148                 -20.0
#
#     Cases in the last 7 days/1M pop  Deaths in the last 7 days  \
# 3                            4027.0                          1
# 5                             591.0                          0
# 6                             776.0                          1
# 9                             977.0                         13
# ...

# %%
df_slim2 = populous_df2 [["Country, Other", "Cases in the last 7 days", "Deaths in the last 7 days", "Population"]]

# %%
df_slim2.head(10)
# Out:
#             Country, Other  Cases in the last 7 days  \
# 3                  Andorra                       312
# 5                 Anguilla                         9
# 6      Antigua and Barbuda                        77
# 9                    Aruba                       105
# 13                 Bahamas                       118
# 16                Barbados                      1989
# 19                  Belize                       738
# 21                 Bermuda                       177
# 22                  Bhutan                      2446
# 27  British Virgin Islands                        53
#
#     Deaths in the last 7 days  Population
# 3                           1       77468
# 5                           0       15222
# 6                           1       99258
# 9                          13      107509
# 13                          4      399401
# 16                         12      287952
# 19                         13      409450
# ...

# %% [markdown]
# 5.Import another dataset with a common column

# %%
merge_df = pd.merge(df_slim1, df_slim2, on = 'Deaths in the last 7 days')

# %%
merge_df
# Out:
#    Country, Other_x  Cases in the last 7 days_x  Deaths in the last 7 days  \
# 0             China                         837                          0
# 1             China                         837                          0
# 2             China                         837                          0
# 3             China                         837                          0
# 4             China                         837                          0
# 5             China                         837                          0
# 6             China                         837                          0
# 7             China                         837                          0
# 8             China                         837                          0
# 9             China                         837                          0
# 10            China                         837                          0
# ...
