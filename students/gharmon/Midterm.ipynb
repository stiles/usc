# %%
import pandas as pd
import altair as alt

# %% [markdown]
# #### Import data

# %%
desert_df= pd.read_csv('data/Food_Desert_2015.csv')

# %%
desert_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3143 entries, 0 to 3142
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             3143 non-null   int64
#  1   fips             3143 non-null   int64
#  2   state_fips       3143 non-null   int64
#  3   county_fips      3143 non-null   int64
#  4   county_name      3143 non-null   object
#  5   state_name       3143 non-null   object
#  6   state_abbr       3143 non-null   object
#  7   metro_nonmetro   3143 non-null   object
#  8   desert_pop_2010  3143 non-null   int64
#  9   total_pop_2010   3143 non-null   int64
# dtypes: int64(6), object(4)
# memory usage: 245.7+ KB

# %% [markdown]
# #### Clean up columns

# %%
desert_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3143 entries, 0 to 3142
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             3143 non-null   int64
#  1   fips             3143 non-null   int64
#  2   state_fips       3143 non-null   int64
#  3   county_fips      3143 non-null   int64
#  4   county_name      3143 non-null   object
#  5   state_name       3143 non-null   object
#  6   state_abbr       3143 non-null   object
#  7   metro_nonmetro   3143 non-null   object
#  8   desert_pop_2010  3143 non-null   int64
#  9   total_pop_2010   3143 non-null   int64
# dtypes: int64(6), object(4)
# memory usage: 245.7+ KB

# %%
grouped = desert_df.groupby("county_name")["state_name"].count()

# %%
grouped.head()
# Out:
# county_name
# Abbeville County    1
# Acadia Parish       1
# Accomack County     1
# Ada County          1
# Adair County        4
# Name: state_name, dtype: int64

# %% [markdown]
# #### Get counties grouped by states and only find states with mean food desert populations over 500k

# %%
desert_df[desert_df['desert_pop_2010'] > 500000].groupby("state_name").mean()
# Out:
#                  year          fips  state_fips  county_fips  desert_pop_2010  \
# state_name
# Arizona        2015.0   4013.000000         4.0    13.000000     1.446218e+06
# California     2015.0   6053.000000         6.0    53.000000     8.940330e+05
# Florida        2015.0  12070.500000        12.0    70.500000     5.802725e+05
# Georgia        2015.0  13107.666667        13.0   107.666667     5.845397e+05
# Illinois       2015.0  17031.000000        17.0    31.000000     8.518610e+05
# Massachusetts  2015.0  25017.000000        25.0    17.000000     6.985940e+05
# Michigan       2015.0  26125.000000        26.0   125.000000     6.400590e+05
# Minnesota      2015.0  27053.000000        27.0    53.000000     5.280950e+05
# Missouri       2015.0  29189.000000        29.0   189.000000     5.669840e+05
# Nevada         2015.0  32003.000000        32.0     3.000000     6.287910e+05
# New York       2015.0  36103.000000        36.0   103.000000     8.106830e+05
# Ohio           2015.0  39049.000000        39.0    49.000000     5.901160e+05
# Pennsylvania   2015.0  42003.000000        42.0     3.000000     5.542290e+05
# Tennessee      2015.0  47157.000000        47.0   157.000000     5.349690e+05
# Texas          2015.0  48241.666667        48.0   241.666667     9.591457e+05
# Washington     2015.0  53033.000000        53.0    33.000000     6.944810e+05
#
#                total_pop_2010
# state_name
# Arizona          3.817117e+06
# California       3.533004e+06
# Florida          1.139895e+06
# Georgia          8.046600e+05
# Illinois         5.194675e+06
# Massachusetts    1.503085e+06
# Michigan         1.202362e+06
# Minnesota        1.152425e+06
# Missouri         9.989540e+05
# Nevada           1.951269e+06
# New York         1.493350e+06
# Ohio             1.163414e+06
# Pennsylvania     1.223348e+06
# Tennessee        9.276440e+05
# Texas            1.963907e+06
# Washington       1.931249e+06

# %% [markdown]
# ### What states have the largest number of total citizens living in a food desert? (at least 1,000,000 in a food desert)

# %%
desert_df[desert_df['desert_pop_2010'] > 1000000].groupby("state_name").mean().sort_values('desert_pop_2010', ascending=False).head(10)
# Out:
#               year     fips  state_fips  county_fips  desert_pop_2010  \
# state_name
# Arizona     2015.0   4013.0         4.0         13.0        1446218.0
# Texas       2015.0  48320.0        48.0        320.0        1433914.0
# California  2015.0   6051.0         6.0         51.0        1190613.0
#
#             total_pop_2010
# state_name
# Arizona          3817117.0
# Texas            2950746.5
# California       6004123.0

# %% [markdown]
# #### What states in the US have the smallest number of total citizens living in food deserts?

# %%
desert_df.groupby("state_name").mean().sort_values('desert_pop_2010', ascending=True).head(10)
# Out:
#                  year          fips  state_fips  county_fips  desert_pop_2010  \
# state_name
# North Dakota   2015.0  38053.000000        38.0    53.000000      7039.792453
# South Dakota   2015.0  46068.121212        46.0    68.121212      7894.015152
# Montana        2015.0  30056.000000        30.0    56.000000      8513.464286
# Nebraska       2015.0  31093.000000        31.0    93.000000      9113.344086
# Vermont        2015.0  50014.000000        50.0    14.000000     11692.428571
# Kentucky       2015.0  21120.000000        21.0   120.000000     12136.141667
# Alaska         2015.0   2153.517241         2.0   153.517241     12599.793103
# West Virginia  2015.0  54055.000000        54.0    55.000000     13169.345455
# Iowa           2015.0  19099.000000        19.0    99.000000     13925.484848
# Kansas         2015.0  20105.000000        20.0   105.000000     13992.895238
#
#                total_pop_2010
# state_name
# North Dakota     12690.396226
# South Dakota     12336.060606
# Montana          17668.125000
# Nebraska         19638.075269
# Vermont          44695.785714
# Kentucky         36161.391667
# Alaska           24490.724138
# West Virginia    33690.800000
# Iowa             30771.262626
# Kansas           27172.552381

# %% [markdown]
# #### Make a column that's the number of people living in a food desert based on the population of that state (number of people in a food desert per capita)

# %%
desert_df['desert_pop_per100k'] = desert_df['desert_pop_2010']/desert_df['total_pop_2010']*100000

# %%
desert_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3143 entries, 0 to 3142
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   year                3143 non-null   int64
#  1   fips                3143 non-null   int64
#  2   state_fips          3143 non-null   int64
#  3   county_fips         3143 non-null   int64
#  4   county_name         3143 non-null   object
#  5   state_name          3143 non-null   object
#  6   state_abbr          3143 non-null   object
#  7   metro_nonmetro      3143 non-null   object
#  8   desert_pop_2010     3143 non-null   int64
#  9   total_pop_2010      3143 non-null   int64
#  10  desert_pop_per100k  3143 non-null   float64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 270.2+ KB

# %% [markdown]
# #### What counties have the highest rate of people living in food deserts per 100,000 people?

# %%
desert_df.sort_values('desert_pop_per100k', ascending=False).head(5)
# Out:
#       year   fips  state_fips  county_fips       county_name  state_name  \
# 3142  2015  56045          56           45     Weston County     Wyoming
# 1806  2015  35021          35           21    Harding County  New Mexico
# 1740  2015  31173          31          173   Thurston County    Nebraska
# 1745  2015  31183          31          183    Wheeler County    Nebraska
# 1751  2015  32009          32            9  Esmeralda County      Nevada
#
#      state_abbr   metro_nonmetro  desert_pop_2010  total_pop_2010  \
# 3142         WY  Nonmetropolitan             7208            7208
# 1806         NM  Nonmetropolitan              695             695
# 1740         NE  Nonmetropolitan             6940            6940
# 1745         NE  Nonmetropolitan              818             818
# 1751         NV  Nonmetropolitan              783             783
#
#       desert_pop_per100k
# 3142            100000.0
# 1806            100000.0
# 1740            100000.0
# 1745            100000.0
# 1751            100000.0

# %%
### Well, that gave me the counties where every single person lives in a food desert. 
##In other words, counties that are food deserts themselves. 
### Let's limit per 10,000k value to 9,500.

# %%
desert_pct_under_100k = desert_df[desert_df['desert_pop_per100k'] < 95500]

# %%
desert_pct_under_100k.groupby("county_name").mean().sort_values('desert_pop_per100k', ascending=False).head(10)
# Out:
#                       year     fips  state_fips  county_fips  desert_pop_2010  \
# county_name
# Nye County          2015.0  32023.0        32.0         23.0          41401.0
# Plaquemines Parish  2015.0  22075.0        22.0         75.0          21616.0
# Hockley County      2015.0  48219.0        48.0        219.0          21218.0
# Wetzel County       2015.0  54103.0        54.0        103.0          15165.0
# Latah County        2015.0  16057.0        16.0         57.0          33427.0
# Gonzales County     2015.0  48177.0        48.0        177.0          17693.0
# Yazoo County        2015.0  28163.0        28.0        163.0          24857.0
# Ouachita County     2015.0   5103.0         5.0        103.0          22754.0
# Milam County        2015.0  48331.0        48.0        331.0          21465.0
# Kossuth County      2015.0  19109.0        19.0        109.0          13463.0
#
#                     total_pop_2010  desert_pop_per100k
# county_name
# Nye County                 43946.0        94208.801711
# Plaquemines Parish         23042.0        93811.301102
# Hockley County             22935.0        92513.625463
# Wetzel County              16583.0        91449.074353
# Latah County               37244.0        89751.369348
# Gonzales County            19807.0        89327.005604
# Yazoo County               28065.0        88569.392482
# Ouachita County            26120.0        87113.323124
# Milam County               24757.0        86702.750737
# Kossuth County             15543.0        86617.770057

# %%
desert_pct_under_100k.sort_values('desert_pop_per100k', ascending=False).head(5)
# Out:
#       year   fips  state_fips  county_fips         county_name     state_name  \
# 1758  2015  32023          32           23          Nye County         Nevada
# 1150  2015  22075          22           75  Plaquemines Parish      Louisiana
# 2311  2015  44001          44            1      Bristol County   Rhode Island
# 2632  2015  48219          48          219      Hockley County          Texas
# 3044  2015  54103          54          103       Wetzel County  West Virginia
#
#      state_abbr   metro_nonmetro  desert_pop_2010  total_pop_2010  \
# 1758         NV  Nonmetropolitan            41401           43946
# 1150         LA     Metropolitan            21616           23042
# 2311         RI     Metropolitan            46687           49875
# 2632         TX  Nonmetropolitan            21218           22935
# 3044         WV  Nonmetropolitan            15165           16583
#
#       desert_pop_per100k
# 1758        94208.801711
# 1150        93811.301102
# 2311        93608.020050
# 2632        92513.625463
# 3044        91449.074353

# %% [markdown]
# #### What states have the most and least per capita rates of people living in food deserts?

# %%
desert_df.groupby("state_name").mean().sort_values('desert_pop_per100k', ascending=False).head(10)
# Out:
#                 year          fips  state_fips  county_fips  desert_pop_2010  \
# state_name
# South Dakota  2015.0  46068.121212        46.0    68.121212      7894.015152
# New Mexico    2015.0  35030.151515        35.0    30.151515     35579.606061
# North Dakota  2015.0  38053.000000        38.0    53.000000      7039.792453
# Nevada        2015.0  32045.529412        32.0    45.529412     59929.176471
# Alaska        2015.0   2153.517241         2.0   153.517241     12599.793103
# Montana       2015.0  30056.000000        30.0    56.000000      8513.464286
# Nebraska      2015.0  31093.000000        31.0    93.000000      9113.344086
# Utah          2015.0  49029.000000        49.0    29.000000     47479.689655
# Wyoming       2015.0  56023.000000        56.0    23.000000     15255.782609
# Kansas        2015.0  20105.000000        20.0   105.000000     13992.895238
#
#               total_pop_2010  desert_pop_per100k
# state_name
# South Dakota    12336.060606        77428.092911
# New Mexico      62399.363636        71688.749992
# North Dakota    12690.396226        71650.772450
# Nevada         158855.941176        66659.162017
# Alaska          24490.724138        66566.678696
# Montana         17668.125000        66303.295060
# Nebraska        19638.075269        64482.208135
# Utah            95306.379310        63547.587479
# Wyoming         24505.478261        63516.772189
# Kansas          27172.552381        61686.274979

# %%
desert_df.groupby("state_name").mean().sort_values('desert_pop_per100k', ascending=True).head(10)
# Out:
#                         year     fips  state_fips  county_fips  \
# state_name
# District of Columbia  2015.0  11001.0        11.0          1.0
# Kentucky              2015.0  21120.0        21.0        120.0
# Vermont               2015.0  50014.0        50.0         14.0
# Maine                 2015.0  23016.0        23.0         16.0
# New York              2015.0  36062.0        36.0         62.0
# Pennsylvania          2015.0  42067.0        42.0         67.0
# Tennessee             2015.0  47095.0        47.0         95.0
# Indiana               2015.0  18092.0        18.0         92.0
# Michigan              2015.0  26083.0        26.0         83.0
# North Carolina        2015.0  37100.0        37.0        100.0
#
#                       desert_pop_2010  total_pop_2010  desert_pop_per100k
# state_name
# District of Columbia     33769.000000   601723.000000         5612.050728
# Kentucky                 12136.141667    36161.391667        20354.158685
# Vermont                  11692.428571    44695.785714        20561.384080
# Maine                    22935.812500    83022.562500        23923.962125
# New York                 66095.000000   312550.032258        28682.169043
# Pennsylvania             69997.925373   189587.746269        29686.537347
# Tennessee                32744.557895    66801.105263        32754.765340
# Indiana                  32121.793478    70476.108696        32855.980684
# Michigan                 46947.759036   119080.000000        33775.159395
# North Carolina           43314.270000    95354.830000        34703.051824

# %%
##desert_pop_under_10k.groupby("county_name").sum().sort_values('desert_pop_per10k', ascending=False).head(10)

# %% [markdown]
# #### How about what counties have the most people in a food desert per capita, that are metropolitan counties? (For counties with per capita food desert population less than 95,500)

# %%
metro_counties = desert_df[desert_df['metro_nonmetro'] == 'Metropolitan']

# %%
metro_counties.head(5)
# Out:
#    year  fips  state_fips  county_fips     county_name state_name state_abbr  \
# 0  2015  1001           1            1  Autauga County    Alabama         AL
# 1  2015  1003           1            3  Baldwin County    Alabama         AL
# 3  2015  1007           1            7     Bibb County    Alabama         AL
# 4  2015  1009           1            9   Blount County    Alabama         AL
# 7  2015  1015           1           15  Calhoun County    Alabama         AL
#
#   metro_nonmetro  desert_pop_2010  total_pop_2010  desert_pop_per100k
# 0   Metropolitan            38885           54571        71255.795203
# 1   Metropolitan            82751          182265        45401.475873
# 3   Metropolitan                0           22915            0.000000
# 4   Metropolitan            15781           57322        27530.442064
# 7   Metropolitan            68635          118572        57884.660797

# %%
metro_counties[metro_counties['desert_pop_per100k'] < 95500].groupby("county_name").sum().sort_values('desert_pop_per100k', ascending=False).head(10)
# Out:
#                     year    fips  state_fips  county_fips  desert_pop_2010  \
# county_name
# Washington County  28210  490754         489         1754           965486
# Madison County     22165  261173         260         1173           615962
# Jefferson County   26195  337111         336         1111          1275328
# Montgomery County  14105  252921         252          921          1784943
# Douglas County     12090  180280         180          280           506679
# Jackson County     12090  161420         161          420           653569
# Warren County      14105  230133         229         1133           324341
# Franklin County    16120  317384         317          384           767787
# Benton County      12090  163042         163           42           288975
# Hamilton County     8060  135264         135          264           906891
#
#                    total_pop_2010  desert_pop_per100k
# county_name
# Washington County         2034413       624258.589429
# Madison County            1126383       533388.377946
# Jefferson County          2833416       467308.392641
# Montgomery County         3258636       414937.260266
# Douglas County            1128394       350357.697472
# Jackson County            1250960       343742.395550
# Warren County              617197       315469.825471
# Franklin County           1669997       301465.831736
# Benton County              555476       284132.627165
# Hamilton County           1422530       283765.376031

# %% [markdown]
# #### How many metropolitan counties have over 70,000 people per 100,000 living in a food desert?

# %%
big_desert_metro = metro_counties[metro_counties['desert_pop_per100k'] > 70000]

# %%
##big_desert_metro = metro_counties[metro_counties['desert_pop_per100k'] > 80000]

# %%
big_desert_metro.value_counts('metro_nonmetro')
# Out:
# metro_nonmetro
# Metropolitan    128
# dtype: int64

# %% [markdown]
# #### How many non-metropolitan counties had a food desert population rate of under per 10,000 residents

# %%
nonmetro_counties = desert_df[desert_df['metro_nonmetro'] == 'Nonmetropolitan']

# %%
nonmetro_counties[nonmetro_counties['desert_pop_per100k'] < 1000].groupby("county_name").sum().sort_values('desert_pop_per100k', ascending=False).head(10)
# Out:
#                     year   fips  state_fips  county_fips  desert_pop_2010  \
# county_name
# Adair County        2015  19001          19            1                0
# Orange County       2015  18117          18          117                0
# Mitchell County     2015  37121          37          121                0
# Monroe County       4030  60282          60          282                0
# Montmorency County  2015  26119          26          119                0
# Morris County       2015  48343          48          343                0
# Morrow County       2015  41049          41           49                0
# Motley County       2015  48345          48          345                0
# Moultrie County     2015  17139          17          139                0
# Nemaha County       2015  31127          31          127                0
#
#                     total_pop_2010  desert_pop_per100k
# county_name
# Adair County                  7682                 0.0
# Orange County                19840                 0.0
# Mitchell County              15579                 0.0
# Monroe County                25605                 0.0
# Montmorency County            9765                 0.0
# Morris County                12934                 0.0
# Morrow County                11173                 0.0
# Motley County                 1210                 0.0
# Moultrie County              14846                 0.0
# Nemaha County                 7248                 0.0

# %% [markdown]
# #### How many metropolitan counties have over 70,000 people per 100,000 living in a food desert?

# %%
big_desert_nonmetro = nonmetro_counties[nonmetro_counties['desert_pop_per100k'] > 70000]

# %%
big_desert_nonmetro.value_counts('metro_nonmetro')
# Out:
# metro_nonmetro
# Nonmetropolitan    487
# dtype: int64

# %%
bigger_desert_nonmetro = nonmetro_counties[nonmetro_counties['desert_pop_per100k'] > 90000]

# %%
bigger_desert_nonmetro.value_counts('metro_nonmetro')
# Out:
# metro_nonmetro
# Nonmetropolitan    332
# dtype: int64

# %% [markdown]
# #### Let's look the number of counties in each state that are metropolitan or nonmetropolitan

# %%
metro_count = desert_df[desert_df['metro_nonmetro'] == 'Metropolitan']

# %%
metro_count.value_counts('state_name')
# Out:
# state_name
# Texas                   82
# Virginia                81
# Georgia                 74
# North Carolina          46
# Florida                 44
# Indiana                 44
# Tennessee               42
# Illinois                40
# Ohio                    38
# New York                38
# California              37
# Pennsylvania            37
# Kentucky                35
# Louisiana               35
# Missouri                34
# Alabama                 29
# Minnesota               27
# South Carolina          26
# Michigan                26
# Wisconsin               26
# West Virginia           21
# New Jersey              21
# Washington              21
# Iowa                    21
# Arkansas                20
# Kansas                  19
# Maryland                19
# Oklahoma                18
# Mississippi             17
# Colorado                17
# Oregon                  13
# Nebraska                13
# Idaho                   12
# Massachusetts           11
# Utah                    10
# South Dakota             8
# Arizona                  8
# New Mexico               7
# Connecticut              7
# North Dakota             6
# Maine                    5
# Montana                  5
# Rhode Island             5
# Nevada                   4
# Delaware                 3
# Alaska                   3
# Vermont                  3
# New Hampshire            3
# Hawaii                   3
# Wyoming                  2
# District of Columbia     1
# dtype: int64

# %%
nonmetro_count = desert_df[desert_df['metro_nonmetro'] == 'Nonmetropolitan']

# %%
nonmetro_count.value_counts('state_name')
# Out:
# state_name
# Texas             172
# Kansas             86
# Georgia            85
# Kentucky           85
# Missouri           81
# Nebraska           80
# Iowa               78
# Mississippi        65
# Illinois           62
# Minnesota          60
# Oklahoma           59
# South Dakota       58
# Michigan           57
# Arkansas           55
# North Carolina     54
# Tennessee          53
# Virginia           53
# Montana            51
# Ohio               50
# Indiana            48
# Colorado           47
# North Dakota       47
# Wisconsin          46
# Alabama            38
# West Virginia      34
# Idaho              32
# Pennsylvania       30
# Louisiana          29
# Alaska             26
# New Mexico         26
# New York           24
# Oregon             23
# Florida            23
# California         21
# Wyoming            21
# South Carolina     20
# Utah               19
# Washington         18
# Nevada             13
# Maine              11
# Vermont            11
# New Hampshire       7
# Arizona             7
# Maryland            5
# Massachusetts       3
# Hawaii              2
# Connecticut         1
# dtype: int64

# %% [markdown]
# ### Let's make a graph of the states with the least and with the most people living in food deserts.

# %%
alt.Chart(desert_df).mark_bar(color='red').encode(x='desert_pop_2010', y='state_name').properties(width=650)
# Out:
# alt.Chart(...)

# %%
leastdeserts = desert_df.groupby("state_name").mean().sort_values('desert_pop_per100k', ascending=True).head(7)

# %%
leastdeserts.plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='state_name'>

# %%
mostdeserts = desert_df.groupby("state_name").mean().sort_values('desert_pop_per100k', ascending=False).head(7)

# %%
mostdeserts.plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='state_name'>
