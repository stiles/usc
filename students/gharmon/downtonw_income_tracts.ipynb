# %%
# %load_ext lab_black
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %%
import pandas as pd

# %%
df = pd.read_csv("income_tracts_in_around_downtown.csv")

# %%
df.head()
# Out:
#    statefp10  countyfp10  tractce10     geoid10   name10  \
# 0          6          37     207502  6037207502  2075.02
# 1          6          37     207301  6037207301  2073.01
# 2          6          37     207501  6037207501  2075.01
# 3          6          37     207302  6037207302  2073.02
# 4          6          37     207710  6037207710  2077.10
#
#              namelsad10 mtfcc10 funcstat10  aland10  awater10  ...  \
# 0  Census Tract 2075.02   G5020          S   418373         0  ...
# 1  Census Tract 2073.01   G5020          S   430089         0  ...
# 2  Census Tract 2075.01   G5020          S   134326         0  ...
# 3  Census Tract 2073.02   G5020          S   256159         0  ...
# 4  Census Tract 2077.10   G5020          S  1101544         0  ...
#
#    125000_149999_error  150000_199999_error 200000_more_error  index_right  \
# 0                 60.0                 85.0              69.0           53
# ...

# %%
df.loc[
    :,
    ~df.columns.isin(
        [
            "statefp10",
            "countyfp10",
            "tractce10",
            "name10",
            "aland10",
            "funcstat10",
            "awater10",
        ]
    ),
]
# Out:
#        geoid10            namelsad10 mtfcc10  intptlat10  intptlon10  \
# 0   6037207502  Census Tract 2075.02   G5020   34.052707 -118.253084
# 1   6037207301  Census Tract 2073.01   G5020   34.046537 -118.251617
# 2   6037207501  Census Tract 2075.01   G5020   34.056442 -118.252967
# 3   6037207302  Census Tract 2073.02   G5020   34.047550 -118.247726
# 4   6037207710  Census Tract 2077.10   G5020   34.046866 -118.261685
# 5   6037207400     Census Tract 2074   G5020   34.056194 -118.246650
# 6   6037206300     Census Tract 2063   G5020   34.041111 -118.243213
# 7   6037224010  Census Tract 2240.10   G5020   34.036764 -118.265898
# 8   6037226002  Census Tract 2260.02   G5020   34.032620 -118.247769
# 9   6037206200     Census Tract 2062   G5020   34.046994 -118.241598
# 10  6037207900     Census Tract 2079   G5020   34.040528 -118.260168
# 11  6037207102  Census Tract 2071.02   G5020   34.059285 -118.239510
# 12  6037207101  Census Tract 2071.01   G5020   34.061203 -118.244818
# ...
