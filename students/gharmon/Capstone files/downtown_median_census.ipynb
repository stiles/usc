# %%
# %load_ext lab_black
import pandas as pd

# %%
df = pd.read_csv(
    "income_tracts_in_around_downtown.csv",
    dtype={
        "statefp10": str,
        "countyfp10": str,
        "tractce10": str,
        "geoid10": str,
        "name10": str,
        "namelsad10": str,
        "mtfcc10": str,
    },
)

# %%
downtown_tracts = df["name10"].to_list()

# %%
downtown_tracts
# Out:
# ['2075.02',
#  '2073.01',
#  '2075.01',
#  '2073.02',
#  '2077.10',
#  '2074',
#  '2063',
#  '2240.10',
#  '2260.02',
#  '2062',
#  '2079',
#  '2071.02',
#  '2071.01',
#  '2060.31',
#  '2060.20',
#  '2080',
#  '2240.20',
#  '2244.10',
#  '2270.10',
#  '5324',
#  '2242',
#  '2093',
#  '2092',
#  '2100.10',
#  '2281',
#  '1977',
#  '1976',
#  '2260.01']

# %%
census_df = pd.read_csv("ACSST5Y2019.all_tracts_S1901.csv")

# %%
###census_downtown_tract_df = census_df[census_df.index.isin(downtown_tracts.index)]

# %%
df.sort_values("name10", ascending=False)
# Out:
#    statefp10 countyfp10 tractce10      geoid10   name10            namelsad10  \
# 19        06        037    532400  06037532400     5324     Census Tract 5324
# 24        06        037    228100  06037228100     2281     Census Tract 2281
# 18        06        037    227010  06037227010  2270.10  Census Tract 2270.10
# 8         06        037    226002  06037226002  2260.02  Census Tract 2260.02
# 27        06        037    226001  06037226001  2260.01  Census Tract 2260.01
# 17        06        037    224410  06037224410  2244.10  Census Tract 2244.10
# 20        06        037    224200  06037224200     2242     Census Tract 2242
# 16        06        037    224020  06037224020  2240.20  Census Tract 2240.20
# 7         06        037    224010  06037224010  2240.10  Census Tract 2240.10
# 23        06        037    210010  06037210010  2100.10  Census Tract 2100.10
# 21        06        037    209300  06037209300     2093     Census Tract 2093
# ...
