# %% [markdown]
# # Week 6: Show off your pandas skills
# What's the relationship between vaccination rates and post-vaccination deaths?

# %% [markdown]
# #### Load python tools:

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datadesk/california-coronavirus-data/master/cdph-vaccination-county-totals.csv')

# %% [markdown]
# ### Explore the dataset

# %%
df.head()
# Out:
#          date     county  fips  population  doses_administered  \
# 0  2022-02-21    Alameda     1   1643700.0             3504668
# 1  2022-02-21     Alpine     3      1148.0                1865
# 2  2022-02-21     Amador     5     37829.0               54202
# 3  2022-02-21      Butte     7    227075.0              288365
# 4  2022-02-21  Calaveras     9     45235.0               63249
#
#    new_doses_administered  pfizer_doses  new_pfizer_doses  moderna_doses  \
# 0                     493     2138982.0               299      1065487.0
# 1                       0          73.0                 0         1769.0
# 2                       7       15852.0                 3        35882.0
# 3                      30      141977.0                15       130419.0
# 4                       4       26952.0                 0        33965.0
#
#    new_moderna_doses  ...  new_jj_doses  partially_vaccinated  \
# 0                143  ...            13              107066.0
# ...

# %% [markdown]
# #### Numbers of rows in data

# %%
len(df)
# Out:
# 45182

# %% [markdown]
# #### Sort by fully vaccinated individuals

# %%
df.sort_values('county', ascending=False).head()
# Out:
#              date county  fips  population  doses_administered  \
# 45181  2020-01-05   Yuba   115     75493.0                   0
# 27085  2020-11-12   Yuba   115     75493.0                   2
# 17225  2021-05-01   Yuba   115     75493.0               36145
# 27317  2020-11-08   Yuba   115     75493.0                   2
# 39787  2020-04-07   Yuba   115     75493.0                   0
#
#        new_doses_administered  pfizer_doses  new_pfizer_doses  moderna_doses  \
# 45181                       0           0.0                 0            0.0
# 27085                       0           0.0                 0            2.0
# 17225                     226       11244.0                99        22609.0
# 27317                       0           0.0                 0            2.0
# 39787                       0           0.0                 0            0.0
#
#        new_moderna_doses  ...  new_jj_doses  partially_vaccinated  \
# ...

# %% [markdown]
# #### How many individuals are fully vaccinated?

# %%
df.value_counts('fully_vaccinated')
# Out:
# fully_vaccinated
# 0.0          15803
# 1.0           1476
# 2.0            678
# 3.0            315
# 5.0            315
#              ...
# 38083.0          1
# 38067.0          1
# 38049.0          1
# 38048.0          1
# 7225579.0        1
# Length: 21432, dtype: int64

# %% [markdown]
# #### Explore distributions

# %%
df.describe(exclude=None)
# Out:
#                fips    population  doses_administered  new_doses_administered  \
# count  45182.000000  4.518200e+04        4.518200e+04            45182.000000
# mean      58.000000  6.749787e+05        3.715605e+05             1551.621619
# std       33.481709  1.456937e+06        1.325799e+06             6044.001580
# min        1.000000  1.148000e+03        0.000000e+00                0.000000
# 25%       29.000000  4.523500e+04        0.000000e+00                0.000000
# 50%       58.000000  1.834385e+05        4.359000e+03               15.000000
# 75%       87.000000  7.322120e+05        1.599985e+05              640.000000
# max      115.000000  1.009805e+07        1.837491e+07           139634.000000
#
#        pfizer_doses  new_pfizer_doses  moderna_doses  new_moderna_doses  \
# count  4.518200e+04      45182.000000   4.518200e+04       45182.000000
# mean   2.090199e+05        871.709730   1.462932e+05         578.497366
# ...

# %% [markdown]
# #### Most recent

# %%
latest_df = df[df["date"] == df["date"].max()]

# %%
len(latest_df)
# Out:
# 58

# %% [markdown]
# #### Columns

# %%
essential_df = latest_df[["county", "fully_vaccinated_percent", "population"]]

# %%
essential_df.head()
# Out:
#       county  fully_vaccinated_percent  population
# 0    Alameda                  0.817470   1643700.0
# 1     Alpine                  0.625436      1148.0
# 2     Amador                  0.545111     37829.0
# 3      Butte                  0.504397    227075.0
# 4  Calaveras                  0.533857     45235.0

# %% [markdown]
# ### Post-vaccination deaths

# %%
post_df = pd.read_csv('https://raw.githubusercontent.com/stiles/usc/main/data/raw/post_vacc.csv')

# %%
post_df.head()
# Out:
#      date        area area_type  unvaccinated_cases  vaccinated_cases  \
# 0  2/1/21  California     State               13848                22
# 1  2/2/21  California     State               11380                17
# 2  2/3/21  California     State               10355                26
# 3  2/4/21  California     State                9022                17
# 4  2/5/21  California     State                8416                17
#
#    boosted_cases  unvaccinated_hosp  vaccinated_hosp  boosted_hosp  \
# 0              0                761                0             0
# 1              0                590                0             0
# 2              0                545                0             0
# 3              0                478                0             0
# 4              0                488                0             0
#
#    unvaccinated_deaths  ...  population_boosted  unvaccinated_cases_per_100k  \
# ...

# %% [markdown]
# #### Which area had the most vaccinated deaths per 100k?

# %%
post_df.sort_values("vaccinated_deaths_per_100k", ascending=False).head()
# Out:
#         date        area area_type  unvaccinated_cases  vaccinated_cases  \
# 365   2/1/22  California     State               11342              8564
# 368   2/4/22  California     State                7537              5636
# 360  1/27/22  California     State               15399             12563
# 359  1/26/22  California     State               17759             15176
# 366   2/2/22  California     State                9494              7228
#
#      boosted_cases  unvaccinated_hosp  vaccinated_hosp  boosted_hosp  \
# 365           5344                306              167            73
# 368           3936                220              102            46
# 360           6961                469              245           101
# 359           8268                456              255           102
# 366           4843                259              142            56
#
#      unvaccinated_deaths  ...  population_boosted  \
# 365                   92  ...            12177907
# ...

# %% [markdown]
# #### Columns

# %%
essential_post_df = post_df[
    ["area", "vaccinated_cases", "vaccinated_hosp", "vaccinated_deaths_per_100k"]
]

# %%
essential_post_df.head()
# Out:
#          area  vaccinated_cases  vaccinated_hosp  vaccinated_deaths_per_100k
# 0  California                22                0                         NaN
# 1  California                17                0                         NaN
# 2  California                26                0                         NaN
# 3  California                17                0                         NaN
# 4  California                17                0                         NaN

# %% [markdown]
# ### Merging the data

# %%
merge_df = pd.merge(essential_df, essential_post_df, on="fully_vaccinated")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-2c341b51f653> in <module>
# ----> 1 merge_df = pd.merge(essential_df, essential_post_df, on="fully_vaccinated")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     666             self.right_join_keys,
#     667             self.join_names,
# --> 668         ) = self._get_merge_keys()
#     669
# ...
