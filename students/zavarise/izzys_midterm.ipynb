# %% [markdown]
# ### Izzy's Midterm

# %% [markdown]
# ### Import python tools

# %%
import pandas as pd

# %% [markdown]
# ## Read data

# %%
url = 'https://data.lacity.org/api/views/amvf-fr72/rows.csv?accessType=DOWNLOAD'

# %%
src = pd.read_csv(url, low_memory=False)

# %%
df = src.copy()

# %% [markdown]
# ### What does the data look like?

# %%
df.head()
# Out:
#    Report ID Report Type             Arrest Date    Time  Area ID  \
# 0    6115382     BOOKING  01/29/2021 12:00:00 AM  2035.0        1
# 1    6303598     BOOKING  01/06/2022 12:00:00 AM  2345.0        6
# 2  211218835         RFC  09/01/2021 12:00:00 AM  1230.0       12
# 3  211611663         RFC  09/20/2021 12:00:00 AM  1735.0       16
# 4  211911576         RFC  07/27/2021 12:00:00 AM   850.0       19
#
#      Area Name  Reporting District  Age Sex Code Descent Code  ...  \
# 0      Central                 176   36        M            H  ...
# 1    Hollywood                 646   27        M            B  ...
# 2  77th Street                1207   22        M            H  ...
# 3     Foothill                1675   24        M            H  ...
# 4      Mission                1961   51        F            H  ...
#
#        Disposition Description                                  Address  \
# 0       FELONY COMPLAINT FILED                                      7TH
# 1                          NaN          CAHUENGA                     BL
# 2  MISDEMEANOR COMPLAINT FILED  4700 S  VERMONT                      AV
# 3  MISDEMEANOR COMPLAINT FILED  8800    SUNLAND                      BL
# 4  MISDEMEANOR COMPLAINT FILED  9400 N  SEPULVEDA                    BL
#
#   Cross Street      LAT       LON                   Location  \
# 0         WALL  34.0420 -118.2485   POINT (-118.2485 34.042)
# 1        SELMA  34.0998 -118.3295  POINT (-118.3295 34.0998)
# 2          NaN  33.9996 -118.2915  POINT (-118.2915 33.9996)
# 3          NaN   0.0000    0.0000                POINT (0 0)
# 4          NaN  34.2388 -118.4677  POINT (-118.4677 34.2388)
#
#              Booking Date Booking Time       Booking Location  \
# 0  01/29/2021 12:00:00 AM       2155.0  METRO - JAIL DIVISION
# 1  01/07/2022 12:00:00 AM        118.0              HOLLYWOOD
# 2                     NaN          NaN                    NaN
# 3                     NaN          NaN                    NaN
# 4                     NaN          NaN                    NaN
#
#    Booking Location Code
# 0                 4273.0
# 1                 4206.0
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ## How many arrests are there?

# %%
len(df)
# Out:
# 140823

# %% [markdown]
# ### What do the last five rows of data look like?

# %%
df.tail()
# Out:
#         Report ID Report Type             Arrest Date    Time  Area ID  \
# 140818    6063905     BOOKING  12/03/2020 12:00:00 AM  2210.0       14
# 140819    5996524     BOOKING  08/21/2020 12:00:00 AM  1545.0        2
# 140820    6072080     BOOKING  12/18/2020 12:00:00 AM  1856.0        8
# 140821    6020060     BOOKING  09/26/2020 12:00:00 AM  2220.0       16
# 140822    5916226     BOOKING  04/15/2020 12:00:00 AM  2240.0       20
#
#        Area Name  Reporting District  Age Sex Code Descent Code  ...  \
# 140818   Pacific                1413   32        M            B  ...
# 140819   Rampart                 245   23        M            B  ...
# 140820   West LA                 805   24        M            H  ...
# 140821  Foothill                1664   43        M            H  ...
# 140822   Olympic                2058   32        F            H  ...
#
#             Disposition Description                          Address  \
# 140818       FELONY COMPLAINT FILED                     ABBOT KINNEY
# 140819         CITY ATTORNEY REJECT  6TH                          ST
# 140820                          NaN                        SEPULVEDA
# 140821  MISDEMEANOR COMPLAINT FILED                         GLENOAKS
# 140822  MISDEMEANOR COMPLAINT FILED                          VERMONT
#
#                            Cross Street      LAT       LON  \
# 140818                         BROADWAY  33.9921 -118.4721
# 140819  GRAND VIEW                   ST  34.0605 -118.2770
# 140820                           MORAGA  34.0776 -118.4693
# 140821                         BRANFORD  34.2554 -118.3934
# 140822                          OLYMPIC  34.0526 -118.2916
#
#                          Location            Booking Date Booking Time  \
# 140818  POINT (-118.4721 33.9921)  12/04/2020 12:00:00 AM        330.0
# 140819   POINT (-118.277 34.0605)  08/21/2020 12:00:00 AM       2153.0
# 140820  POINT (-118.4693 34.0776)  12/18/2020 12:00:00 AM       2317.0
# 140821  POINT (-118.3934 34.2554)  09/27/2020 12:00:00 AM         14.0
# 140822  POINT (-118.2916 34.0526)  04/16/2020 12:00:00 AM        131.0
#
#              Booking Location  Booking Location Code
# 140818                PACIFIC                 4214.0
# 140819                77TH ST                 4212.0
# 140820                77TH ST                 4212.0
# 140821      VALLEY - JAIL DIV                 4279.0
# 140822  METRO - JAIL DIVISION                 4273.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### What is the average age of arrest?

# %%
df['Age'].mean()
# Out:
# 34.69282716601691

# %% [markdown]
# ### Show me the 10 oldest people who were arrested?

# %%
df.sort_values('Age', ascending=False).head(10)
# Out:
#         Report ID Report Type             Arrest Date    Time  Area ID  \
# 9464      6292727     BOOKING  12/13/2021 12:00:00 AM  2030.0        6
# 137354    6041140     BOOKING  10/27/2020 12:00:00 AM  2130.0        9
# 88667   212004101         RFC  12/19/2020 12:00:00 AM  1140.0       20
# 39812     6121295     BOOKING  02/07/2021 12:00:00 AM  2010.0        3
# 4035      6220960     BOOKING  07/26/2021 12:00:00 AM  1750.0        1
# 125106    5972367     BOOKING  07/15/2020 12:00:00 AM   950.0       12
# 74234     6214857     BOOKING  07/14/2021 12:00:00 AM  2245.0       12
# 138940    5892463     BOOKING  03/04/2020 12:00:00 AM  1205.0        2
# 52961     6216075     BOOKING  07/16/2021 12:00:00 AM  2230.0        6
# 34220   211114989         RFC  11/03/2021 12:00:00 AM  1330.0       11
#
#           Area Name  Reporting District  Age Sex Code Descent Code  ...  \
# 9464      Hollywood                 626   96        F            B  ...
# 137354     Van Nuys                 941   95        F            B  ...
# 88667       Olympic                2017   94        F            H  ...
# 39812     Southwest                 398   91        M            B  ...
# 4035        Central                 138   90        M            O  ...
# 125106  77th Street                1245   90        M            O  ...
# 74234   77th Street                1263   89        M            B  ...
# 138940      Rampart                 236   88        M            O  ...
# 52961     Hollywood                 632   88        M            W  ...
# 34220     Northeast                1123   87        F            H  ...
#
#               Disposition Description  \
# 9464      MISDEMEANOR COMPLAINT FILED
# 137354         FELONY COMPLAINT FILED
# 88667     MISDEMEANOR COMPLAINT FILED
# 39812     MISDEMEANOR COMPLAINT FILED
# 4035           FELONY COMPLAINT FILED
# 125106  849(B)(1) PC/TECHNICAL ARREST
# 74234          FELONY COMPLAINT FILED
# 138940           CITY ATTORNEY REJECT
# 52961     MISDEMEANOR COMPLAINT FILED
# 34220     MISDEMEANOR COMPLAINT FILED
#
#                                         Address  \
# 9464    2900    DURAN                        DR
# 137354  5600    VAN NUYS                     BL
# 88667   3600 W  3RD                          ST
# 39812           MARTIN LUTHER KI             BL
# 4035     200 S  CENTRAL                      AV
# 125106  6700 S  NORMANDIE                    AV
# 74234   1800 W  84TH                         PL
# 138940   200 S  BONNIE BRAE                  ST
# 52961   1500 N  LAUREL                       AV
# 34220   2900    GLENMANOR                    PL
#
#                            Cross Street      LAT       LON  \
# 9464                                NaN  34.1129 -118.3280
# 137354                              NaN  34.1766 -118.4589
# 88667                               NaN  34.0709 -118.2941
# 39812   FIGUEROA                     ST  34.0074 -118.2850
# 4035                                NaN  34.0471 -118.2394
# 125106                              NaN  33.9778 -118.3003
# 74234                               NaN  33.9618 -118.3112
# 138940                              NaN  34.0644 -118.2686
# 52961                               NaN  34.0980 -118.3643
# 34220                               NaN  34.1153 -118.2654
#
#                          Location            Booking Date Booking Time  \
# 9464     POINT (-118.328 34.1129)  12/13/2021 12:00:00 AM       2123.0
# 137354  POINT (-118.4589 34.1766)  10/28/2020 12:00:00 AM         43.0
# 88667   POINT (-118.2941 34.0709)                     NaN          NaN
# 39812    POINT (-118.285 34.0074)  02/07/2021 12:00:00 AM       2130.0
# 4035    POINT (-118.2394 34.0471)  07/26/2021 12:00:00 AM       2003.0
# 125106  POINT (-118.3003 33.9778)  07/15/2020 12:00:00 AM       1415.0
# 74234   POINT (-118.3112 33.9618)  07/15/2021 12:00:00 AM         59.0
# 138940  POINT (-118.2686 34.0644)  03/04/2020 12:00:00 AM       1441.0
# 52961    POINT (-118.3643 34.098)  07/17/2021 12:00:00 AM         13.0
# 34220   POINT (-118.2654 34.1153)                     NaN          NaN
#
#              Booking Location  Booking Location Code
# 9464                HOLLYWOOD                 4206.0
# 137354      VALLEY - JAIL DIV                 4279.0
# 88667                     NaN                    NaN
# 39812                 77TH ST                 4212.0
# 4035    METRO - JAIL DIVISION                 4273.0
# 125106                77TH ST                 4212.0
# 74234                 77TH ST                 4212.0
# 138940  METRO - JAIL DIVISION                 4273.0
# 52961               HOLLYWOOD                 4206.0
# 34220                     NaN                    NaN
#
# [10 rows x 25 columns]

# %%
df.describe()
# Out:
#           Report ID           Time        Area ID  Reporting District  \
# count  1.408230e+05  140815.000000  140823.000000       140823.000000
# mean   4.676000e+07    1371.509314      10.769462         1123.253368
# std    8.063673e+07     668.119781       6.109651          609.948247
# min    1.062984e+06       1.000000       1.000000          100.000000
# 25%    5.995566e+06     925.000000       6.000000          625.000000
# 50%    6.169038e+06    1500.000000      12.000000         1211.000000
# 75%    6.296490e+06    1930.000000      15.000000         1591.000000
# max    2.221056e+08    2400.000000      21.000000         2198.000000
#
#                  Age  Charge Group Code            LAT            LON  \
# count  140823.000000      130345.000000  140823.000000  140823.000000
# mean       34.692827          13.536331      32.943316    -114.428459
# std        12.306957           7.547073       6.102153      21.192658
# min         0.000000           1.000000       0.000000    -118.667600
# 25%        26.000000           7.000000      33.993300    -118.433900
# 50%        32.000000          13.000000      34.052200    -118.310800
# 75%        42.000000          22.000000      34.170000    -118.271200
# max        96.000000          99.000000      34.332700       0.000000
#
#         Booking Time  Booking Location Code
# count  112238.000000          112235.000000
# mean     1247.423333            4248.858404
# std       768.944207              32.242171
# min         1.000000            4201.000000
# 25%       451.000000            4212.000000
# 50%      1348.000000            4273.000000
# 75%      1947.000000            4279.000000
# max      2359.000000            4279.000000

# %%
df.groupby(['Report Type'])['Sex Code'].mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py in array_func(values)
#     339             try:
# --> 340                 result = self.grouper._cython_operation(
#     341                     "aggregate", values, how, axis=data.ndim - 1, min_count=min_count
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     998         ngroups = self.ngroups
# --> 999         return cy_op.cython_operation(
#    1000             values=values,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     659
# --> 660         return self._cython_op_ndim_compat(
#     661             values,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py in _cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, **kwargs)
#     501             values2d = values[None, :]
# --> 502             res = self._call_cython_op(
#     503                 values2d,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py in _call_cython_op(self, values, min_count, ngroups, comp_ids, mask, **kwargs)
#     561         out_shape = self._get_output_shape(ngroups, values)
# --> 562         func, values = self.get_cython_func_and_vals(values, is_numeric)
#     563         out_dtype = self.get_out_dtype(values.dtype)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py in get_cython_func_and_vals(self, values, is_numeric)
#     204
# --> 205         func = self._get_cython_function(kind, how, values.dtype, is_numeric)
#     206
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py in _get_cython_function(cls, kind, how, dtype, is_numeric)
#     169                 # raise NotImplementedError here rather than TypeError later
# --> 170                 raise NotImplementedError(
#     171                     f"function is not implemented for this dtype: "
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1601         try:
# -> 1602             x = float(x)
#    1603         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1605             try:
# -> 1606                 x = complex(x)
#    1607             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# /var/folders/w5/3gbnk82j74g1qmgs1yk83qxr0000gn/T/ipykernel_39521/464685059.py in <module>
# ----> 1 df.groupby(['Report Type'])['Sex Code'].mean()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only)
#    1685         numeric_only = self._resolve_numeric_only(numeric_only)
#    1686
# -> 1687         result = self._cython_agg_general(
#    1688             "mean",
#    1689             alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     350             return result
#     351
# --> 352         result = array_func(objvals)
#     353
#     354         ser = self.obj._constructor(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py in array_func(values)
#     346                 # try to python agg
#     347                 # TODO: shouldn't min_count matter?
# --> 348                 result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#     349
#     350             return result
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, values, ndim, alt)
#    1396         #  should always be preserved by the implemented aggregations
#    1397         # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1398         res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1399
#    1400         if isinstance(values, Categorical):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#    1047
#    1048         else:
# -> 1049             result = self._aggregate_series_fast(obj, func)
#    1050
#    1051         npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py in _aggregate_series_fast(self, obj, func)
#    1072         ids = ids.take(indexer)
#    1073         sgrouper = libreduction.SeriesGrouper(obj, func, ids, ngroups)
# -> 1074         result, _ = sgrouper.get_result()
#    1075         return result
#    1076
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/reduction.pyx in pandas._libs.reduction._BaseGrouper._apply_to_group()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    1687         result = self._cython_agg_general(
#    1688             "mean",
# -> 1689             alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1690             numeric_only=numeric_only,
#    1691         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10367
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10369         return self._stat_function(
#   10370             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10371         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10352                 name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   10353             )
# > 10354         return self._reduce(
#   10355             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10356         )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4390                 )
#    4391             with np.errstate(all="ignore"):
# -> 4392                 return op(delegate, skipna=skipna, **kwds)
#    4393
#    4394     def _reindex_indexer(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      91             try:
#      92                 with np.errstate(invalid="ignore"):
# ---> 93                     return f(*args, **kwargs)
#      94             except ValueError as e:
#      95                 # we want to transform an object array
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     153                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154             else:
# --> 155                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     156
#     157             return result
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     408             mask = isna(values)
#     409
# --> 410         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     411
#     412         if datetimelike:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     663
#     664     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 665     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     666
#     667     if axis is not None and getattr(the_sum, "ndim", False):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1607             except ValueError as err:
#    1608                 # e.g. "foo"
# -> 1609                 raise TypeError(f"Could not convert {x} to numeric") from err
#    1610     return x
#    1611
#
# TypeError: Could not convert ... to numeric
