# %% [markdown]
# # IMDB movie ratings

# %% [markdown]
# #### Import python tools

# %%
# %load_ext lab_black

# %%
import pandas as pd

# %% [markdown]
# ## Read our data

# %%
url = "https://raw.githubusercontent.com/stiles/usc/main/data/raw/imdb_1000.csv"

# %% [markdown]
# #### Create a movies dataframe, and sort it by title

# %%
movies_df = pd.read_csv(url)

# %% [markdown]
# #### First five rows?

# %%
movies_df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# #### Use the `describe()` method to see the distribution

# %%
movies_df.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %% [markdown]
# ---

# %% [markdown]
# ## Categorization exercise

# %% [markdown]
# #### What do you consider a 'long' movie?

# %%
movie_long = 175

# %%
movie_long = movies_df["duration"].mean() + movies_df["duration"].std()

# %%
movie_long
# Out:
# 147.19758083721905

# %% [markdown]
# #### Boolean categorization function

# %%
def categorize_long_movies(time):
    if time >= movie_long:
        return True
    else:
        return False

# %% [markdown]
# #### Apply that to our duration column as a new column

# %%
movies_df["is_long"] = movies_df["duration"].apply(categorize_long_movies)

# %%
movies_df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list  is_long
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...    False
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']     True
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...     True
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...     True
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....     True

# %%
movies_df.is_long.value_counts()
# Out:
# False    845
# True     134
# Name: is_long, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## Looping exercise

# %%
for g in movies_df["genre"].unique():
    print("https://www.imdb.com/search/title/?genres=" + g)
# Out:
# https://www.imdb.com/search/title/?genres=Crime
# https://www.imdb.com/search/title/?genres=Action
# https://www.imdb.com/search/title/?genres=Drama
# https://www.imdb.com/search/title/?genres=Western
# https://www.imdb.com/search/title/?genres=Adventure
# https://www.imdb.com/search/title/?genres=Biography
# https://www.imdb.com/search/title/?genres=Comedy
# https://www.imdb.com/search/title/?genres=Animation
# https://www.imdb.com/search/title/?genres=Mystery
# https://www.imdb.com/search/title/?genres=Horror
# https://www.imdb.com/search/title/?genres=Film-Noir
# https://www.imdb.com/search/title/?genres=Sci-Fi
# https://www.imdb.com/search/title/?genres=History
# https://www.imdb.com/search/title/?genres=Thriller
# https://www.imdb.com/search/title/?genres=Family
# https://www.imdb.com/search/title/?genres=Fantasy

# %%
# https://www.imdb.com/search/title/?genres=comedy

# %%
movies_df["genre_url"] = (
    "https://www.imdb.com/search/title/?genres+" + movies_df["genre"]
)

# %%
movies_df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list  is_long  \
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...    False
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']     True
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...     True
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...     True
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....     True
#
#                                           genre_url
# 0   https://www.imdb.com/search/title/?genres+Crime
# 1   https://www.imdb.com/search/title/?genres+Crime
# 2   https://www.imdb.com/search/title/?genres+Crime
# 3  https://www.imdb.com/search/title/?genres+Action
# 4   https://www.imdb.com/search/title/?genres+Crime

# %% [markdown]
# ---

# %% [markdown]
# ### Questions

# %% [markdown]
# #### How many crime movies vs. other types?

# %%
movies_df.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %% [markdown]
# #### Which movie featuring Jack Nicholson had the highest star rating?

# %%
movies_df[movies_df["actors_list"].str.contains("Jack Nicholson")].sort_values(
    "star_rating", ascending=False
)
# Out:
#      star_rating                            title content_rating      genre  \
# 16           8.7  One Flew Over the Cuckoo's Nest              R      Drama
# 49           8.5                     The Departed              R      Crime
# 62           8.5                      The Shining              R     Horror
# 130          8.3                        Chinatown              R      Drama
# 578          7.8               As Good as It Gets          PG-13     Comedy
# 716          7.6                   A Few Good Men              R      Drama
# 801          7.6                           Batman          PG-13     Action
# 943          7.4                  The Bucket List          PG-13  Adventure
# 944          7.4              Terms of Endearment              R     Comedy
#
#      duration                                        actors_list  is_long  \
# 16        133  [u'Jack Nicholson', u'Louise Fletcher', u'Mich...    False
# 49        151  [u'Leonardo DiCaprio', u'Matt Damon', u'Jack N...     True
# 62        146  [u'Jack Nicholson', u'Shelley Duvall', u'Danny...    False
# 130       130  [u'Jack Nicholson', u'Faye Dunaway', u'John Hu...    False
# 578       139  [u'Jack Nicholson', u'Helen Hunt', u'Greg Kinn...    False
# 716       138  [u'Tom Cruise', u'Jack Nicholson', u'Demi Moore']    False
# 801       126  [u'Michael Keaton', u'Jack Nicholson', u'Kim B...    False
# 943        97  [u'Jack Nicholson', u'Morgan Freeman', u'Sean ...    False
# 944       132  [u'Shirley MacLaine', u'Debra Winger', u'Jack ...    False
#
#                                              genre_url
# 16     https://www.imdb.com/search/title/?genres+Drama
# 49     https://www.imdb.com/search/title/?genres+Crime
# 62    https://www.imdb.com/search/title/?genres+Horror
# 130    https://www.imdb.com/search/title/?genres+Drama
# 578   https://www.imdb.com/search/title/?genres+Comedy
# 716    https://www.imdb.com/search/title/?genres+Drama
# 801   https://www.imdb.com/search/title/?genres+Action
# 943  https://www.imdb.com/search/title/?genres+Adve...
# 944   https://www.imdb.com/search/title/?genres+Comedy

# %% [markdown]
# #### How does the average duration of dramas compare with other genres?

# %%
movies_df.groupby(["genre"])["duration"].mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %% [markdown]
# #### How many movies contain Al Pacino?

# %%
len(movies_df[movies_df["actors_list"].str.contains("Al Pacino")])
# Out:
# 13

# %% [markdown]
# #### What's the longest PG-13 action movie?

# %%
action = movies_df[movies_df["genre"] == "Action"]

# %%
action[action["content_rating"] == "PG-13"].sort_values("duration", ascending=False)
# Out:
#      star_rating                                            title  \
# 385          8.0                                        Spartacus
# 684          7.7                                     The Big Blue
# 43           8.5                            The Dark Knight Rises
# 433          7.9                                           Avatar
# 3            9.0                                  The Dark Knight
# 11           8.8                                        Inception
# 686          7.7                                  Minority Report
# 380          8.0                                    Casino Royale
# 177          8.2                                     The Avengers
# 568          7.8                                          Skyfall
# 113          8.3                                    Batman Begins
# 661          7.7     Star Wars: Episode III - Revenge of the Sith
# 976          7.4  Master and Commander: The Far Side of the World
# 301          8.0                                        Furious 7
# 517          7.8              Captain America: The Winter Soldier
# 871          7.5                                               X2
# 488          7.8                          Star Trek Into Darkness
# 532          7.8                               X-Men: First Class
# 591          7.7                        The Count of Monte Cristo
# 248          8.1                       X-Men: Days of Future Past
# 539          7.8                                     The Fugitive
# 623          7.7                   Dawn of the Planet of the Apes
# 858          7.5               Sherlock Holmes: A Game of Shadows
# 726          7.6                                  Sherlock Holmes
# 118          8.3               Indiana Jones and the Last Crusade
# 312          8.0                                        Star Trek
# 699          7.6                                The Fifth Element
# 434          7.9                                         Iron Man
# 801          7.6                                           Batman
# 196          8.1                          Guardians of the Galaxy
# 437          7.9                   Crouching Tiger, Hidden Dragon
# 809          7.6                          House of Flying Daggers
# 366          8.0                                         Serenity
# 411          7.9                              The Bourne Identity
# 240          8.1                             The Bourne Ultimatum
# 391          8.0                                 Edge of Tomorrow
# 856          7.5                      Scott Pilgrim vs. the World
# 812          7.6                         Star Trek: First Contact
# 567          7.8                             The Bourne Supremacy
# 787          7.6                   Rise of the Planet of the Apes
# 653          7.7                                         Fearless
# 954          7.4                                            X-Men
# 403          7.9                                       Ying xiong
# 455          7.9                                            Taken
#
#     content_rating   genre  duration  \
# 385          PG-13  Action       197
# 684          PG-13  Action       168
# 43           PG-13  Action       165
# 433          PG-13  Action       162
# 3            PG-13  Action       152
# 11           PG-13  Action       148
# 686          PG-13  Action       145
# 380          PG-13  Action       144
# 177          PG-13  Action       143
# 568          PG-13  Action       143
# 113          PG-13  Action       140
# 661          PG-13  Action       140
# 976          PG-13  Action       138
# 301          PG-13  Action       137
# 517          PG-13  Action       136
# 871          PG-13  Action       134
# 488          PG-13  Action       132
# 532          PG-13  Action       132
# 591          PG-13  Action       131
# 248          PG-13  Action       131
# 539          PG-13  Action       130
# 623          PG-13  Action       130
# 858          PG-13  Action       129
# 726          PG-13  Action       128
# 118          PG-13  Action       127
# 312          PG-13  Action       127
# 699          PG-13  Action       126
# 434          PG-13  Action       126
# 801          PG-13  Action       126
# 196          PG-13  Action       121
# 437          PG-13  Action       120
# 809          PG-13  Action       119
# 366          PG-13  Action       119
# 411          PG-13  Action       119
# 240          PG-13  Action       115
# 391          PG-13  Action       113
# 856          PG-13  Action       112
# 812          PG-13  Action       111
# 567          PG-13  Action       108
# 787          PG-13  Action       105
# 653          PG-13  Action       104
# 954          PG-13  Action       104
# 403          PG-13  Action        99
# 455          PG-13  Action        93
#
#                                            actors_list  is_long  \
# 385  [u'Kirk Douglas', u'Laurence Olivier', u'Jean ...     True
# 684  [u'Jean-Marc Barr', u'Jean Reno', u'Rosanna Ar...     True
# 43   [u'Christian Bale', u'Tom Hardy', u'Anne Hatha...     True
# 433  [u'Sam Worthington', u'Zoe Saldana', u'Sigourn...     True
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...     True
# 11   [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...     True
# 686  [u'Tom Cruise', u'Colin Farrell', u'Samantha M...    False
# 380     [u'Daniel Craig', u'Eva Green', u'Judi Dench']    False
# 177  [u'Robert Downey Jr.', u'Chris Evans', u'Scarl...    False
# 568  [u'Daniel Craig', u'Javier Bardem', u'Naomie H...    False
# 113  [u'Christian Bale', u'Michael Caine', u'Ken Wa...    False
# 661  [u'Hayden Christensen', u'Natalie Portman', u'...    False
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...    False
# 301  [u'Vin Diesel', u'Paul Walker', u'Dwayne Johns...    False
# 517  [u'Chris Evans', u'Samuel L. Jackson', u'Scarl...    False
# 871  [u'Patrick Stewart', u'Hugh Jackman', u'Halle ...    False
# 488  [u'Chris Pine', u'Zachary Quinto', u'Zoe Salda...    False
# 532  [u'James McAvoy', u'Michael Fassbender', u'Jen...    False
# 591  [u'Jim Caviezel', u'Guy Pearce', u'Richard Har...    False
# 248  [u'Patrick Stewart', u'Ian McKellen', u'Hugh J...    False
# 539  [u'Harrison Ford', u'Tommy Lee Jones', u'Sela ...    False
# 623  [u'Gary Oldman', u'Keri Russell', u'Andy Serkis']    False
# 858  [u'Robert Downey Jr.', u'Jude Law', u'Jared Ha...    False
# 726  [u'Robert Downey Jr.', u'Jude Law', u'Rachel M...    False
# 118  [u'Harrison Ford', u'Sean Connery', u'Alison D...    False
# 312  [u'Chris Pine', u'Zachary Quinto', u'Simon Pegg']    False
# 699  [u'Bruce Willis', u'Milla Jovovich', u'Gary Ol...    False
# 434  [u'Robert Downey Jr.', u'Gwyneth Paltrow', u'T...    False
# 801  [u'Michael Keaton', u'Jack Nicholson', u'Kim B...    False
# 196  [u'Chris Pratt', u'Vin Diesel', u'Bradley Coop...    False
# 437  [u'Yun-Fat Chow', u'Michelle Yeoh', u'Ziyi Zha...    False
# 809  [u'Ziyi Zhang', u'Takeshi Kaneshiro', u'Andy L...    False
# 366  [u'Nathan Fillion', u'Gina Torres', u'Chiwetel...    False
# 411  [u'Franka Potente', u'Matt Damon', u'Chris Coo...    False
# 240  [u'Matt Damon', u'\xc9dgar Ram\xedrez', u'Joan...    False
# 391    [u'Tom Cruise', u'Emily Blunt', u'Bill Paxton']    False
# 856  [u'Michael Cera', u'Mary Elizabeth Winstead', ...    False
# 812  [u'Patrick Stewart', u'Jonathan Frakes', u'Bre...    False
# 567  [u'Matt Damon', u'Franka Potente', u'Joan Allen']    False
# 787  [u'James Franco', u'Andy Serkis', u'Freida Pin...    False
# 653               [u'Jet Li', u'Li Sun', u'Yong Dong']    False
# 954  [u'Patrick Stewart', u'Hugh Jackman', u'Ian Mc...    False
# 403  [u'Jet Li', u'Tony Chiu Wai Leung', u'Maggie C...    False
# 455  [u'Liam Neeson', u'Maggie Grace', u'Famke Jans...    False
#
#                                             genre_url
# 385  https://www.imdb.com/search/title/?genres+Action
# 684  https://www.imdb.com/search/title/?genres+Action
# 43   https://www.imdb.com/search/title/?genres+Action
# 433  https://www.imdb.com/search/title/?genres+Action
# 3    https://www.imdb.com/search/title/?genres+Action
# 11   https://www.imdb.com/search/title/?genres+Action
# 686  https://www.imdb.com/search/title/?genres+Action
# 380  https://www.imdb.com/search/title/?genres+Action
# 177  https://www.imdb.com/search/title/?genres+Action
# 568  https://www.imdb.com/search/title/?genres+Action
# 113  https://www.imdb.com/search/title/?genres+Action
# 661  https://www.imdb.com/search/title/?genres+Action
# 976  https://www.imdb.com/search/title/?genres+Action
# 301  https://www.imdb.com/search/title/?genres+Action
# 517  https://www.imdb.com/search/title/?genres+Action
# 871  https://www.imdb.com/search/title/?genres+Action
# 488  https://www.imdb.com/search/title/?genres+Action
# 532  https://www.imdb.com/search/title/?genres+Action
# 591  https://www.imdb.com/search/title/?genres+Action
# 248  https://www.imdb.com/search/title/?genres+Action
# 539  https://www.imdb.com/search/title/?genres+Action
# 623  https://www.imdb.com/search/title/?genres+Action
# 858  https://www.imdb.com/search/title/?genres+Action
# 726  https://www.imdb.com/search/title/?genres+Action
# 118  https://www.imdb.com/search/title/?genres+Action
# 312  https://www.imdb.com/search/title/?genres+Action
# 699  https://www.imdb.com/search/title/?genres+Action
# 434  https://www.imdb.com/search/title/?genres+Action
# 801  https://www.imdb.com/search/title/?genres+Action
# 196  https://www.imdb.com/search/title/?genres+Action
# 437  https://www.imdb.com/search/title/?genres+Action
# 809  https://www.imdb.com/search/title/?genres+Action
# 366  https://www.imdb.com/search/title/?genres+Action
# 411  https://www.imdb.com/search/title/?genres+Action
# 240  https://www.imdb.com/search/title/?genres+Action
# 391  https://www.imdb.com/search/title/?genres+Action
# 856  https://www.imdb.com/search/title/?genres+Action
# 812  https://www.imdb.com/search/title/?genres+Action
# 567  https://www.imdb.com/search/title/?genres+Action
# 787  https://www.imdb.com/search/title/?genres+Action
# 653  https://www.imdb.com/search/title/?genres+Action
# 954  https://www.imdb.com/search/title/?genres+Action
# 403  https://www.imdb.com/search/title/?genres+Action
# 455  https://www.imdb.com/search/title/?genres+Action

# %% [markdown]
# #### Which genre has the highest star rating?

# %%
movies_df.groupby(["genre"])["star_rating"].mean().sort_values(ascending=False)
# Out:
# genre
# Western      8.255556
# Film-Noir    8.033333
# History      8.000000
# Mystery      7.975000
# Adventure    7.933333
# Sci-Fi       7.920000
# Crime        7.916935
# Animation    7.914516
# Drama        7.902518
# Action       7.884559
# Biography    7.862338
# Family       7.850000
# Comedy       7.822436
# Horror       7.806897
# Fantasy      7.700000
# Thriller     7.680000
# Name: star_rating, dtype: float64

# %% [markdown]
# #### How many movies contain the word 'city'?

# %%
movies_df[movies_df["title"].str.contains("City", case=False)]
# Out:
#      star_rating                      title content_rating    genre  duration  \
# 21           8.7                City of God              R    Crime       130
# 29           8.6                City Lights         PASSED   Comedy        87
# 216          8.1                   Sin City              R    Crime       124
# 583          7.8                  Dark City              R  Mystery       100
# 638          7.7  The City of Lost Children              R  Fantasy       112
#
#                                            actors_list  is_long  \
# 21   [u'Alexandre Rodrigues', u'Matheus Nachtergael...    False
# 29   [u'Charles Chaplin', u'Virginia Cherrill', u'F...    False
# 216  [u'Mickey Rourke', u'Clive Owen', u'Bruce Will...    False
# 583  [u'Rufus Sewell', u'Kiefer Sutherland', u'Jenn...    False
# 638  [u'Ron Perlman', u'Daniel Emilfork', u'Judith ...    False
#
#                                              genre_url
# 21     https://www.imdb.com/search/title/?genres+Crime
# 29    https://www.imdb.com/search/title/?genres+Comedy
# 216    https://www.imdb.com/search/title/?genres+Crime
# 583  https://www.imdb.com/search/title/?genres+Mystery
# 638  https://www.imdb.com/search/title/?genres+Fantasy

# %% [markdown]
# #### Do long movies have a higher average star rating than not long movies?

# %%
movies_df.groupby(["is_long"])["star_rating"].mean()
# Out:
# is_long
# False    7.858698
# True     8.085821
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Are "G" rated movies more popular than "R" rated movies?

# %%
movies_df.groupby(["content_rating"])["star_rating"].mean()
# Out:
# content_rating
# APPROVED     8.027660
# G            7.990625
# GP           7.933333
# NC-17        7.614286
# NOT RATED    8.123077
# PASSED       8.157143
# PG           7.879675
# PG-13        7.828571
# R            7.854783
# TV-MA        8.100000
# UNRATED      7.994737
# X            7.925000
# Name: star_rating, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Bonus questions!

# %% [markdown]
# #### How many movies start with "The"?

# %% [markdown]
# #### What movie title has the most characters in its name?

# %% [markdown]
# #### What percentage of all the movies are in the crime genre?

# %% [markdown]
# #### What percentage of movies featuring Meryl Streep are 'long' vs. 'not long'?
