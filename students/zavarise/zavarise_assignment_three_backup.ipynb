# %% [markdown]
# Assignment 3

# %% [markdown]
# #### Load our Python tools

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/stiles/usc/main/data/raw/demolition_permit.csv')

# %% [markdown]
# ### what does the data look like

# %%
df.head()
# Out:
#    Assessor Book  Assessor Page  Assessor Parcel                    Tract  \
# 0           4286             14               25         OCEAN PARK PLACE
# 1           5054             16               14  WEST ADAMS STREET TRACT
# 2           4316             16               16                 TR 15593
# 3           4249             18                9                 TR 13371
# 4           4265             21               15         SAN VICENTE PARK
#
#   Block  Lot Reference # (Old Permit #)      PCIS Permit #          Status  \
# 0   NaN   54                  18WL90365  18019-30000-00302  Permit Finaled
# 1   NaN   34                  20LA42698  19019-30000-06037  Permit Finaled
# 2   NaN  111                  20WL04473  20019-30000-00183          Issued
# 3   NaN  154                  20WL06439  20019-30000-03251  Permit Finaled
# 4     5   15                  19WL02462  19019-30000-04653  Permit Finaled
#
# ...

# %%
df.columns=df.columns.str.lower()

# %% [markdown]
# Count the number of rows in your data with len()

# %% [markdown]
# ### How many demolition permits were there?

# %%
len(df)
# Out:
# 3044

# %% [markdown]
# Sort your data with sort_values()

# %% [markdown]
# ### Sort by applicant last name

# %%
df.sort_values('applicant last name', ascending=False).head()
# Out:
#       assessor book  assessor page  assessor parcel  \
# 560            4423             12                5
# 1076           4242              4               11
# 60             5534             15                4
# 57             5534             15                4
# 54             5534             15                4
#
#                                      tract block  lot  \
# 560                                TR 9300    50    5
# 1076                               TR 6609   NaN   20
# 60    GRIDER AND HAMILTONS HOLLYWOOD TRACT   NaN  314
# 57    GRIDER AND HAMILTONS HOLLYWOOD TRACT   NaN  314
# 54    GRIDER AND HAMILTONS HOLLYWOOD TRACT   NaN  314
#
#      reference # (old permit #)      pcis permit #          status  \
# 560                   13WL55321  13019-30000-03210  Permit Finaled
# 1076                  13WL54827  13019-30000-02854  Permit Finaled
# 60                    20WL05061  18019-30000-04731          Issued
# ...

# %% [markdown]
# Count values on a column using value_counts('')

# %% [markdown]
# ### How many permits were issued?

# %%
df.value_counts('status')
# Out:
# status
# Permit Finaled        2579
# Issued                 381
# Permit Expired          62
# Refund Completed        15
# Refund in Progress       3
# Intent to Revoke         1
# Permit Closed            1
# Permit Withdrawn         1
# Re-Activate Permit       1
# dtype: int64

# %%
df.describe().round()
# Out:
#        assessor book  assessor page  assessor parcel  project number  \
# count         3044.0         3044.0           3044.0             0.0
# mean          4512.0           15.0             18.0             NaN
# std            804.0            9.0             21.0             NaN
# min           2039.0            1.0              1.0             NaN
# 25%           4247.0            7.0              8.0             NaN
# 50%           4332.0           14.0             15.0             NaN
# 75%           5065.0           22.0             24.0             NaN
# max           7560.0           44.0            900.0             NaN
#
#        event code  address start  address end  zip code  valuation  \
# count         0.0         3044.0       3044.0    3044.0     3044.0
# mean          NaN         4196.0       4196.0   90178.0     7050.0
# std           NaN         4355.0       4355.0     348.0     7148.0
# min           NaN            1.0          1.0   90001.0        0.0
# ...

# %% [markdown]
# ### What are the highest and lowest property valuations?

# %%
df['valuation'].max()
# Out:
# 110000.0

# %%
df['valuation'].min()
# Out:
# 0.0

# %% [markdown]
# ### How many demolition permits were given for properties valued at over $25,000?

# %%
valuation_df.head()
# Out:
#      assessor book  assessor page  assessor parcel        tract block lot  \
# 33            4425             20                1  THE RIVIERA   NaN  77
# 42            4366             32               22      TR 9924     6  24
# 43            4357             11                7      TR 6774   NaN  18
# 136           4494              2                6     TR 28534   NaN   4
# 163           4358              6               42     TR 10016   NaN   1
#
#     reference # (old permit #)      pcis permit #            status  \
# 33                   20ON 0100  20019-30000-01359    Permit Finaled
# 42                   17WL83249  17019-30000-03750    Permit Finaled
# 43                   18WL95391  18019-30000-02789  Refund Completed
# 136                  16WL76843  16019-30000-02218    Permit Finaled
# 163                  17LA79326  17019-30000-00237            Issued
#
#                 status date  ... applicant last name applicant business name  \
# ...

# %%
len(valuation_df)
# Out:
# 52

# %%
valuation_df = df[df['valuation'] > 25000]

# %%
df = pd.read_csv('data/raw/building_permits.csv', low_memory=False)

# %%
df.head()
# Out:
#   Assessor Book Assessor Page Assessor Parcel  \
# 0          2354           016             056
# 1          5017           025             015
# 2          5478           017             040
# 3          5153           026             004
# 4          4422           006             007
#
#                                                Tract Block  Lot  \
# 0                                            TR 4295   NaN  225
# 1                      MILHOUSE VERMONT AVENUE TRACT   NaN    3
# 2                                            TR 2596   NaN   99
# 3  DAY, HINTON AND MATHES RESUBDIVISION OF LOTS 1...   NaN    4
# 4                                            TR 9300    80    3
#
#   Reference # (Old Permit #)      PCIS Permit #          Status  \
# 0                        NaN  13041-10000-24108  Permit Finaled
# 1                        NaN  20041-10000-19010          Issued
# 2                        NaN  19041-10000-34160  Permit Finaled
# ...

# %%
df = df.rename(columns={"Lot":"lot"})

# %%
df.head()
# Out:
#   Assessor Book Assessor Page Assessor Parcel  \
# 0          2354           016             056
# 1          5017           025             015
# 2          5478           017             040
# 3          5153           026             004
# 4          4422           006             007
#
#                                                Tract Block  lot  \
# 0                                            TR 4295   NaN  225
# 1                      MILHOUSE VERMONT AVENUE TRACT   NaN    3
# 2                                            TR 2596   NaN   99
# 3  DAY, HINTON AND MATHES RESUBDIVISION OF LOTS 1...   NaN    4
# 4                                            TR 9300    80    3
#
#   Reference # (Old Permit #)      PCIS Permit #          Status  \
# 0                        NaN  13041-10000-24108  Permit Finaled
# 1                        NaN  20041-10000-19010          Issued
# 2                        NaN  19041-10000-34160  Permit Finaled
# ...

# %%
merge_df = pd.merge(valuation_df, df, on=["lot"])

# %%
merge_df
# Out:
#          assessor book  assessor page  assessor parcel        tract block lot  \
# 0                 4425             20                1  THE RIVIERA   NaN  77
# 1                 4425             20                1  THE RIVIERA   NaN  77
# 2                 4425             20                1  THE RIVIERA   NaN  77
# 3                 4425             20                1  THE RIVIERA   NaN  77
# 4                 4425             20                1  THE RIVIERA   NaN  77
# ...                ...            ...              ...          ...   ...  ..
# 1036923           4214             15               21      TR 3842     H  81
# 1036924           4214             15               21      TR 3842     H  81
# 1036925           4214             15               21      TR 3842     H  81
# 1036926           4214             15               21      TR 3842     H  81
# 1036927           4214             15               21      TR 3842     H  81
#
# ...

# %% [markdown]
# Summary:
