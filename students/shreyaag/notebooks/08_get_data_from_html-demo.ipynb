# %% [markdown]
# # Data from HTML tables: U.S. births

# %%
# %load_ext lab_black
import pandas as pd
import altair as alt

# %% [markdown]
# #### Get url

# %%
url = "https://www.ssa.gov/oact/babynames/numberUSbirths.html"

# %% [markdown]
# #### Read it into a dataframe

# %%
births = pd.read_html(url)[0]
births
# Out:
#      Year of birth     Male   Female    Total
# 0             1880   118399    97606   216005
# 1             1881   108280    98855   207135
# 2             1882   122031   115694   237725
# 3             1883   112475   120059   232534
# 4             1884   122738   137585   260323
# ..             ...      ...      ...      ...
# 136           2016  2022858  1933195  3956053
# 137           2017  1975558  1885970  3861528
# 138           2018  1939284  1855454  3794738
# 139           2019  1914661  1828242  3742903
# 140           2020  1831432  1751046  3582478
#
# [141 rows x 4 columns]

# %% [markdown]
# #### Clean up columns

# %%
births.rename(
    columns={
        "Year of birth": "year",
        "Male": "male",
        "Female": "female",
        "Total": "total",
    },
    inplace=True,
)

# %%
births.head()
# Out:
#    year    male  female   total
# 0  1880  118399   97606  216005
# 1  1881  108280   98855  207135
# 2  1882  122031  115694  237725
# 3  1883  112475  120059  232534
# 4  1884  122738  137585  260323

# %% [markdown]
# #### Convert year

# %%
births.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141 entries, 0 to 140
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    141 non-null    int64
#  1   male    141 non-null    int64
#  2   female  141 non-null    int64
#  3   total   141 non-null    int64
# dtypes: int64(4)
# memory usage: 4.5 KB

# %%
births["year"] = births["year"].astype(str)
births.dtypes
# Out:
# year      object
# male       int64
# female     int64
# total      int64
# dtype: object

# %% [markdown]
# #### Chart it!

# %%
alt.Chart(births).mark_bar(color="orange").encode(x="year:T", y="total").properties(
    width=650
)
# Out:
# alt.Chart(...)

# %%
# births.to_csv('../../data/processed/ssa_births_1880_2020.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# ## Get data from Wikipedia

# %%
# Used in this story:
url2 = "https://en.wikipedia.org/wiki/United_States_midterm_election"
# "https://www.grid.news/story/politics/2022/01/13/what-economic-and-political-indicators-tell-us-about-the-2022-midterms/"

# %%
wiki_df = pd.read_html(url2, header=0)[1]
wiki_df.drop([0], inplace=True)

# %%
wiki_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 1 to 58
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             58 non-null     object
#  1   president        58 non-null     object
#  2   president_party  58 non-null     object
#  3   house_loss       58 non-null     object
#  4   senate_loss      58 non-null     object
# dtypes: object(5)
# memory usage: 2.7+ KB

# %% [markdown]
# #### Clean up the column names

# %% [markdown]
# #### Make them lower case

# %%
wiki_df.columns = (
    wiki_df.columns.str.lower()
    .str.replace(" ", "_", regex=False)
    .str.replace("/", "_", regex=False)
)
wiki_df
# Out:
#     year              president           president_party  \
# 1   1790      George Washington                   None[a]
# 2   1794      George Washington                   None[a]
# 3   1798             John Adams                Federalist
# 4   1802       Thomas Jefferson     Democratic-Republican
# 5   1806       Thomas Jefferson     Democratic-Republican
# 6   1810          James Madison     Democratic-Republican
# 7   1814          James Madison     Democratic-Republican
# 8   1818           James Monroe     Democratic-Republican
# 9   1822           James Monroe     Democratic-Republican
# 10  1826      John Quincy Adams  Democratic-Republican[b]
# 11  1830         Andrew Jackson             Democratic[c]
# 12  1834         Andrew Jackson             Democratic[c]
# 13  1838       Martin Van Buren                Democratic
# 14  1842             John Tyler                   None[d]
# 15  1846          James K. Polk                Democratic
# 16  1850       Millard Fillmore                      Whig
# 17  1854        Franklin Pierce                Democratic
# 18  1858         James Buchanan                Democratic
# 19  1862        Abraham Lincoln                Republican
# 20  1866         Andrew Johnson         National Union[e]
# 21  1870       Ulysses S. Grant                Republican
# 22  1874       Ulysses S. Grant                Republican
# 23  1878    Rutherford B. Hayes                Republican
# 24  1882      Chester A. Arthur                Republican
# 25  1886       Grover Cleveland                Democratic
# 26  1890      Benjamin Harrison                Republican
# 27  1894       Grover Cleveland                Democratic
# 28  1898       William McKinley                Republican
# 29  1902     Theodore Roosevelt                Republican
# 30  1906     Theodore Roosevelt                Republican
# 31  1910    William Howard Taft                Republican
# 32  1914         Woodrow Wilson                Democratic
# 33  1918         Woodrow Wilson                Democratic
# 34  1922      Warren G. Harding                Republican
# 35  1926        Calvin Coolidge                Republican
# 36  1930         Herbert Hoover                Republican
# 37  1934  Franklin D. Roosevelt                Democratic
# 38  1938  Franklin D. Roosevelt                Democratic
# 39  1942  Franklin D. Roosevelt                Democratic
# 40  1946        Harry S. Truman                Democratic
# 41  1950        Harry S. Truman                Democratic
# 42  1954   Dwight D. Eisenhower                Republican
# 43  1958   Dwight D. Eisenhower                Republican
# 44  1962        John F. Kennedy                Democratic
# 45  1966      Lyndon B. Johnson                Democratic
# 46  1970          Richard Nixon                Republican
# 47  1974            Gerald Ford                Republican
# 48  1978           Jimmy Carter                Democratic
# 49  1982          Ronald Reagan                Republican
# 50  1986          Ronald Reagan                Republican
# 51  1990      George H. W. Bush                Republican
# 52  1994           Bill Clinton                Democratic
# 53  1998           Bill Clinton                Democratic
# 54  2002         George W. Bush                Republican
# 55  2006         George W. Bush                Republican
# 56  2010           Barack Obama                Democratic
# 57  2014           Barack Obama                Democratic
# 58  2018           Donald Trump                Republican
#
#              house_loss     senate_loss
# 1         +3: (37 ► 40)    0: (18 ► 18)
# 2         -4: (51 ► 47)   +3: (16 ► 19)
# 3         +3: (57 ► 60)    0: (22 ► 22)
# 4         +1: (38 ► 39)    -6: (15 ► 9)
# 5       +2: (114 ► 116)   +1: (27 ► 28)
# 6       +13: (94 ► 107)    0: (26 ► 26)
# 7       +5: (114 ► 119)   -3: (26 ► 22)
# 8      +13: (145 ► 158)   +2: (28 ► 30)
# 9      +34: (155 ► 189)    0: (44 ► 44)
# 10      -9: (109 ► 100)   -2: (21 ► 19)
# 11     -10: (136 ► 126)   +1: (25 ► 26)
# 12       0: (143 ► 143)   +1: (21 ► 22)
# 13      -3: (128 ► 125)   -7: (35 ► 28)
# 14      -69: (142 ► 73)   -3: (30 ► 27)
# 15     -30: (142 ► 112)   +2: (33 ► 35)
# 16      -22: (108 ► 86)   -3: (36 ► 33)
# 17      -75: (158 ► 83)   -3: (36 ► 33)
# 18      -35: (133 ► 98)   -4: (32 ► 38)
# 19      -23: (108 ► 85)   +1: (31 ► 32)
# 20        +9: (38 ► 47)    0: (10 ► 10)
# 21     -32: (171 ► 139)   -5: (63 ► 58)
# 22     -93: (199 ► 106)  -10: (52 ► 42)
# 23      -4: (136 ► 132)   -7: (38 ► 31)
# 24     -29: (151 ► 118)    0: (37 ► 37)
# 25     -16: (183 ► 167)   +2: (34 ► 36)
# 26      -93: (179 ► 86)   -4: (47 ► 43)
# 27     -127: (220 ► 93)   -4: (44 ► 40)
# 28     -21: (205 ► 189)   +6: (44 ► 50)
# 29      +9: (201 ► 210)    0: (55 ► 55)
# 30     -27: (251 ► 224)   +2: (58 ► 60)
# 31     -56: (219 ► 163)   -9: (59 ► 50)
# 32     -61: (291 ► 230)   +3: (50 ► 53)
# 33     -22: (214 ► 192)   -4: (52 ► 48)
# 34     -77: (302 ► 225)   -7: (60 ► 53)
# 35      -9: (247 ► 238)   -6: (56 ► 50)
# 36     -52: (270 ► 218)   -6: (56 ► 50)
# 37      +9: (313 ► 322)   +9: (60 ► 69)
# 38     -72: (334 ► 262)   -7: (75 ► 68)
# 39     -45: (267 ► 222)   -8: (65 ► 57)
# 40     -54: (242 ► 188)  -10: (56 ► 46)
# 41     -28: (263 ► 235)   -5: (54 ► 49)
# 42     -18: (221 ► 203)   -2: (49 ► 47)
# 43     -48: (201 ► 153)  -12: (47 ► 35)
# 44      -4: (262 ► 258)   +4: (64 ► 68)
# 45     -47: (295 ► 248)   -3: (67 ► 64)
# 46     -12: (192 ► 180)   +2: (43 ► 45)
# 47     -48: (192 ► 144)   -4: (42 ► 38)
# 48     -15: (292 ► 277)   -2: (61 ► 59)
# 49     -26: (192 ► 166)    0: (54 ► 54)
# 50      -5: (182 ► 177)   -8: (53 ► 45)
# 51      -8: (175 ► 167)   -1: (45 ► 44)
# 52     -54: (258 ► 204)  -10: (57 ► 47)
# 53      +4: (207 ► 211)    0: (45 ► 45)
# 54      +8: (221 ► 229)   +2: (49 ► 51)
# 55     -32: (231 ► 199)   -6: (55 ► 49)
# 56     -63: (256 ► 193)   -6: (57 ► 51)
# 57     -13: (201 ► 188)   -9: (53 ► 44)
# 58  -40: (240 ► 200)[f]   +2: (51 ► 53)

# %% [markdown]
# #### Or just rename them entirely

# %%
wiki_df.columns = ["year", "president", "president_party", "house_loss", "senate_loss"]
wiki_df.head()
# Out:
#    year          president        president_party       house_loss  \
# 1  1790  George Washington                None[a]    +3: (37 ► 40)
# 2  1794  George Washington                None[a]    -4: (51 ► 47)
# 3  1798         John Adams             Federalist    +3: (57 ► 60)
# 4  1802   Thomas Jefferson  Democratic-Republican    +1: (38 ► 39)
# 5  1806   Thomas Jefferson  Democratic-Republican  +2: (114 ► 116)
#
#      senate_loss
# 1   0: (18 ► 18)
# 2  +3: (16 ► 19)
# 3   0: (22 ► 22)
# 4   -6: (15 ► 9)
# 5  +1: (27 ► 28)

# %% [markdown]
# #### First five rows

# %%
wiki_df.head()
# Out:
#    year          president        president_party       house_loss  \
# 1  1790  George Washington                None[a]    +3: (37 ► 40)
# 2  1794  George Washington                None[a]    -4: (51 ► 47)
# 3  1798         John Adams             Federalist    +3: (57 ► 60)
# 4  1802   Thomas Jefferson  Democratic-Republican    +1: (38 ► 39)
# 5  1806   Thomas Jefferson  Democratic-Republican  +2: (114 ► 116)
#
#      senate_loss
# 1   0: (18 ► 18)
# 2  +3: (16 ► 19)
# 3   0: (22 ► 22)
# 4   -6: (15 ► 9)
# 5  +1: (27 ► 28)

# %% [markdown]
# #### Filter to presidents after 1900

# %%
#wiki_df[wiki_df['year']>1900]

# %% [markdown]
# #### First, convert data type on year column

# %%
wiki_df["year"] = wiki_df["year"].astype(int)

# %% [markdown]
# #### Now try the filter

# %%
wiki_df[wiki_df["year"] > 1900]
# Out:
#     year              president president_party           house_loss  \
# 29  1902     Theodore Roosevelt      Republican      +9: (201 ► 210)
# 30  1906     Theodore Roosevelt      Republican     -27: (251 ► 224)
# 31  1910    William Howard Taft      Republican     -56: (219 ► 163)
# 32  1914         Woodrow Wilson      Democratic     -61: (291 ► 230)
# 33  1918         Woodrow Wilson      Democratic     -22: (214 ► 192)
# 34  1922      Warren G. Harding      Republican     -77: (302 ► 225)
# 35  1926        Calvin Coolidge      Republican      -9: (247 ► 238)
# 36  1930         Herbert Hoover      Republican     -52: (270 ► 218)
# 37  1934  Franklin D. Roosevelt      Democratic      +9: (313 ► 322)
# 38  1938  Franklin D. Roosevelt      Democratic     -72: (334 ► 262)
# 39  1942  Franklin D. Roosevelt      Democratic     -45: (267 ► 222)
# 40  1946        Harry S. Truman      Democratic     -54: (242 ► 188)
# 41  1950        Harry S. Truman      Democratic     -28: (263 ► 235)
# 42  1954   Dwight D. Eisenhower      Republican     -18: (221 ► 203)
# 43  1958   Dwight D. Eisenhower      Republican     -48: (201 ► 153)
# 44  1962        John F. Kennedy      Democratic      -4: (262 ► 258)
# 45  1966      Lyndon B. Johnson      Democratic     -47: (295 ► 248)
# 46  1970          Richard Nixon      Republican     -12: (192 ► 180)
# 47  1974            Gerald Ford      Republican     -48: (192 ► 144)
# 48  1978           Jimmy Carter      Democratic     -15: (292 ► 277)
# 49  1982          Ronald Reagan      Republican     -26: (192 ► 166)
# 50  1986          Ronald Reagan      Republican      -5: (182 ► 177)
# 51  1990      George H. W. Bush      Republican      -8: (175 ► 167)
# 52  1994           Bill Clinton      Democratic     -54: (258 ► 204)
# 53  1998           Bill Clinton      Democratic      +4: (207 ► 211)
# 54  2002         George W. Bush      Republican      +8: (221 ► 229)
# 55  2006         George W. Bush      Republican     -32: (231 ► 199)
# 56  2010           Barack Obama      Democratic     -63: (256 ► 193)
# 57  2014           Barack Obama      Democratic     -13: (201 ► 188)
# 58  2018           Donald Trump      Republican  -40: (240 ► 200)[f]
#
#        senate_loss
# 29    0: (55 ► 55)
# 30   +2: (58 ► 60)
# 31   -9: (59 ► 50)
# 32   +3: (50 ► 53)
# 33   -4: (52 ► 48)
# 34   -7: (60 ► 53)
# 35   -6: (56 ► 50)
# 36   -6: (56 ► 50)
# 37   +9: (60 ► 69)
# 38   -7: (75 ► 68)
# 39   -8: (65 ► 57)
# 40  -10: (56 ► 46)
# 41   -5: (54 ► 49)
# 42   -2: (49 ► 47)
# 43  -12: (47 ► 35)
# 44   +4: (64 ► 68)
# 45   -3: (67 ► 64)
# 46   +2: (43 ► 45)
# 47   -4: (42 ► 38)
# 48   -2: (61 ► 59)
# 49    0: (54 ► 54)
# 50   -8: (53 ► 45)
# 51   -1: (45 ► 44)
# 52  -10: (57 ► 47)
# 53    0: (45 ► 45)
# 54   +2: (49 ► 51)
# 55   -6: (55 ► 49)
# 56   -6: (57 ► 51)
# 57   -9: (53 ► 44)
# 58   +2: (51 ► 53)

# %% [markdown]
# #### Export

# %%
wiki_df.to_csv("../data/processed/wiki_midterm_gains_losses_party.csv", index=False)
