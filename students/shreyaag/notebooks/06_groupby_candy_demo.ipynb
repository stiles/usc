# %% [markdown]
# # Groupby: Candy!
# Use this method when you want to collapse a dataframe by a categorical column and run an aggregation. For example, if you had a list of candy consumed and wanted to look at the total caleries by brand or type. Let's look.

# %% [markdown]
# #### Load python tools

# %%
import pandas as pd

# %% [markdown]
# #### Read our candy dataset

# %%
# CSV from here: https://docs.google.com/spreadsheets/d/1aLw0zKcOQD7d16kmrjc6nFb_jdXmoEhSTJFzO2i5kPM/edit?usp=sharing

# %%
url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQ5SEEqfwggc80EtHHb4s5eYd06ulLjJbOtNcjcGvktph-\
jCp9d8llRsUNs8BB9hM6Ze4IZ25AC9fRe/pub?gid=0&single=true&output=csv"

# %% [markdown]
# #### Read the data

# %%
candy_df = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQ5SEEqfwggc80EtHHb4s5eYd06ulLjJbOtNcjcGvktph-\
jCp9d8llRsUNs8BB9hM6Ze4IZ25AC9fRe/pub?gid=0&single=true&output=csv")

# %% [markdown]
# #### First five rows

# %%
candy_df.head()
# Out:
#        brand colors   nuts  calories_per_serving  fat_per_serving  \
# 0  Hershey's  Brown  False                    60              3.5
# 1  Hershey's  Brown  False                    60              3.5
# 2  Hershey's  Brown  False                    60              3.5
# 3  Hershey's  Brown  False                    60              3.5
# 4  Hershey's  Brown  False                    60              3.5
#
#       description  satisfacton_score                owner group  id  weight
# 0  Milk Chocolate                  3  The Hershey Company     A   1    13.0
# 1  Milk Chocolate                  9  The Hershey Company     A   2    13.0
# 2  Milk Chocolate                  9  The Hershey Company     A   3    13.0
# 3  Milk Chocolate                  5  The Hershey Company     A   4    13.0
# 4  Milk Chocolate                  7  The Hershey Company     A   5    13.0

# %% [markdown]
# #### Last five rows

# %%
candy_df.tail()
# Out:
#            brand  colors   nuts  calories_per_serving  fat_per_serving  \
# 55  3 Musketeers  Silver  False                    26              0.7
# 56  3 Musketeers  Silver  False                    26              0.7
# 57  3 Musketeers  Silver  False                    26              0.7
# 58  3 Musketeers  Silver  False                    26              0.7
# 59  3 Musketeers  Silver  False                    26              0.7
#
#    description  satisfacton_score         owner group  id  weight
# 55   Candy Bar                  8  Mars Wrigley     B  56    11.3
# 56   Candy Bar                  4  Mars Wrigley     B  57    11.3
# 57   Candy Bar                  8  Mars Wrigley     B  58    11.3
# 58   Candy Bar                  5  Mars Wrigley     B  59    11.3
# 59   Candy Bar                 10  Mars Wrigley     B  60    11.3

# %% [markdown]
# #### How many records?

# %%
print(f"The total number of candy pieces are {len(candy_df)}.")
# Out:
# The total number of candy pieces are 60.

# %% [markdown]
# #### How many calories we talking?

# %%
print(f"The total number of calories you would consume if you ate all 60 pieces of candy are {candy_df['calories_per_serving'].sum()}.")
# Out:
# The total number of calories you would consume if you ate all 60 pieces of candy are 3416.

# %%
print(f"The total number of calories you would consume if you ate all 60 pieces of candy are {candy_df['calories_per_serving'].sum()}.")
candy_df['fat_per_serving'].sum()
# Out:
# The total number of calories you would consume if you ate all 60 pieces of candy are 3416.
# 172.19999999999993

# %% [markdown]
# #### Just those with peanuts

# %%
candy_df[candy_df['nuts']==True]
# Out:
#          brand  colors  nuts  calories_per_serving  fat_per_serving  \
# 17  Almond Joy    Blue  True                    85              4.5
# 18  Almond Joy    Blue  True                    85              4.5
# 19  Almond Joy    Blue  True                    85              4.5
# 20  Almond Joy    Blue  True                    85              4.5
# 21  Almond Joy    Blue  True                    85              4.5
# 22  Almond Joy    Blue  True                    85              4.5
# 23  Almond Joy    Blue  True                    85              4.5
# 24     Reese's  Orange  True                    80              4.5
# 25     Reese's  Orange  True                    80              4.5
# 26     Reese's  Orange  True                    80              4.5
# 27     Reese's  Orange  True                    80              4.5
# 28     Reese's  Orange  True                    80              4.5
# 29     Reese's  Orange  True                    80              4.5
# 30    Snickers   Brown  True                    43              2.0
# 31    Snickers   Brown  True                    43              2.0
# 32    Snickers   Brown  True                    43              2.0
# 33    Snickers   Brown  True                    43              2.0
# 34    Snickers   Brown  True                    43              2.0
# 35    Snickers   Brown  True                    43              2.0
# 36    Snickers   Brown  True                    43              2.0
# 37    Snickers   Brown  True                    43              2.0
# 38    Snickers   Brown  True                    43              2.0
# 39    Snickers   Brown  True                    43              2.0
# 40    Snickers   Brown  True                    43              2.0
# 41    Snickers   Brown  True                    43              2.0
# 42    Snickers   Brown  True                    43              2.0
#
#           description  satisfacton_score                owner group  id  \
# 17          Candy Bar                  2  The Hershey Company     A  18
# 18          Candy Bar                  1  The Hershey Company     A  19
# 19          Candy Bar                  8  The Hershey Company     A  20
# 20          Candy Bar                  6  The Hershey Company     A  21
# 21          Candy Bar                  2  The Hershey Company     A  22
# 22          Candy Bar                  7  The Hershey Company     A  23
# 23          Candy Bar                  6  The Hershey Company     A  24
# 24  Peanut Butter Cup                  4  The Hershey Company     A  25
# 25  Peanut Butter Cup                  1  The Hershey Company     A  26
# 26  Peanut Butter Cup                  2  The Hershey Company     A  27
# 27  Peanut Butter Cup                 10  The Hershey Company     A  28
# 28  Peanut Butter Cup                  2  The Hershey Company     A  29
# 29  Peanut Butter Cup                  9  The Hershey Company     A  30
# 30          Candy Bar                  6         Mars Wrigley     B  31
# 31          Candy Bar                  4         Mars Wrigley     B  32
# 32          Candy Bar                  8         Mars Wrigley     B  33
# 33          Candy Bar                  2         Mars Wrigley     B  34
# 34          Candy Bar                  9         Mars Wrigley     B  35
# 35          Candy Bar                  1         Mars Wrigley     B  36
# 36          Candy Bar                  5         Mars Wrigley     B  37
# 37          Candy Bar                  9         Mars Wrigley     B  38
# 38          Candy Bar                  4         Mars Wrigley     B  39
# 39          Candy Bar                  8         Mars Wrigley     B  40
# 40          Candy Bar                  4         Mars Wrigley     B  41
# 41          Candy Bar                  9         Mars Wrigley     B  42
# 42          Candy Bar                  8         Mars Wrigley     B  43
#
#     weight
# 17    17.0
# 18    17.0
# 19    17.0
# 20    17.0
# 21    17.0
# 22    17.0
# 23    17.0
# 24    15.5
# 25    15.5
# 26    15.5
# 27    15.5
# 28    15.5
# 29    15.5
# 30     9.0
# 31     9.0
# 32     9.0
# 33     9.0
# 34     9.0
# 35     9.0
# 36     9.0
# 37     9.0
# 38     9.0
# 39     9.0
# 40     9.0
# 41     9.0
# 42     9.0

# %% [markdown]
# #### Just those with a user rating above 5

# %%
candy_df[candy_df['satisfacton_score'] > 9]
# Out:
#            brand  colors   nuts  calories_per_serving  fat_per_serving  \
# 27       Reese's  Orange   True                    80             4.50
# 50          Txix    Gold  False                    50             2.33
# 59  3 Musketeers  Silver  False                    26             0.70
#
#           description  satisfacton_score                owner group  id  \
# 27  Peanut Butter Cup                 10  The Hershey Company     A  28
# 50         Cookie Bar                 10         Mars Wrigley     B  51
# 59          Candy Bar                 10         Mars Wrigley     B  60
#
#     weight
# 27    15.5
# 50    10.0
# 59    11.3

# %% [markdown]
# ---

# %% [markdown]
# #### How many of each brand?

# %%
candy_df.groupby(['brand'])['id'].count()
# Out:
# brand
# 3 Musketeers     7
# Almond Joy       7
# Hershey's        9
# KitKat           8
# Reese's          6
# Snickers        13
# Txix            10
# Name: id, dtype: int64

# %%
candy_df.groupby(['brand']).agg({'id':'count','satisfacton_score':'mean'}).reset_index()
# Out:
#           brand  id  satisfacton_score
# 0  3 Musketeers   7           5.714286
# 1    Almond Joy   7           4.571429
# 2     Hershey's   9           4.888889
# 3        KitKat   8           5.375000
# 4       Reese's   6           4.666667
# 5      Snickers  13           5.923077
# 6          Txix  10           4.800000

# %% [markdown]
# #### How many of each color?

# %%
candy_df.groupby(['colors'])['id'].count()
# Out:
# colors
# Blue       7
# Brown     22
# Gold      10
# Orange     6
# Red        8
# Silver     7
# Name: id, dtype: int64

# %% [markdown]
# #### What's the average user rating for each brand?

# %%
candy_df.groupby(['brand'])['satisfacton_score'].mean()
# Out:
# brand
# 3 Musketeers    6.285714
# Almond Joy      6.285714
# Hershey's       6.333333
# KitKat          5.875000
# Reese's         7.000000
# Snickers        4.615385
# Txix            4.200000
# Name: satisfacton_score, dtype: float64

# %% [markdown]
# #### What's the average rating for products related to peanuts?

# %% [markdown]
# #### Nuts vs No Nuts

# %%
candy_df.groupby(['nuts']).agg({'weight':'mean', 'id':'count'}).reset_index()
# Out:
#     nuts     weight  id
# 0  False  12.002941  34
# 1   True  12.653846  26

# %%
candy_df.groupby(['nuts']).agg({'weight':'sum'}).reset_index()
# Out:
#     nuts  weight
# 0  False   408.1
# 1   True   329.0

# %% [markdown]
# #### What's the average rating for products related to color?

# %% [markdown]
# ---

# %% [markdown]
# #### What's the average calories, by type?

# %% [markdown]
# #### Fat?

# %% [markdown]
# #### What if you ate all the Snickers. How many calories?

# %% [markdown]
# #### Which owner has the highest average user score?

# %% [markdown]
# #### What other questions?
