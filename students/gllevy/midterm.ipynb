# %%
import pandas as pd

# %%
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('Affordable_Housing.csv')

# %%
df.columns = df.columns.str.lower().str.replace(" ", "", regex=False)

# %%
df["constructiontype_new"] = (
    df["constructiontype"].str.lower().str.replace(" ", "", regex=False)
)

# %%
df.head()
# Out:
#           apn projectnumber                           name developmentstage  \
# 0  2629019017         40052                PALM VILLAGE SR       In-Service
# 1  6071001013     06-117222  WINDWARD APTS (A/B) (SITE 14)       In-Service
# 2  5545007097     11-117795                     THE GORDON       In-Service
# 3  5050011005     05-117193         LEEWARD APTS. (SITE 7)       In-Service
# 4  5114014020     14-121652        FLORENCE MILLS (SITE 5)       In-Service
#
#    constructiontype                                        siteaddress  \
# 0  NEW CONSTRUCTION    9034 N LAUREL CANYON BLVD  Sun Valley, CA 91352
# 1             REHAB          636 E 108TH ST 1-4  Los Angeles, CA 90059
# 2  NEW CONSTRUCTION              1553 N GORDON ST  HOLLYWOOD, CA 90028
# 3             REHAB            2809 S WEST BLVD  Los Angeles, CA 90016
# 4  NEW CONSTRUCTION  1037 E MARTIN LUTHER KING BLVD  LOS ANGELES, C...
#
#    sitecouncildistrict  site#       sitecommunity  siteunits  \
# ...

# %%
df.tail()
# Out:
#             apn projectnumber                                 name  \
# 531  2604028031     19-125927  SILVA CROSSING (FKA LINK AT SYLMAR)
# 532  5149010949     18-124964          GRAND AVENUE PARCEL Q APTS.
# 533  5114014004     14-121652              FLORENCE MILLS (SITE 4)
# 534  5183005010     09-117211              LAS MARGARITAS (SITE 2)
# 535  5153006024         50035                          UNION POINT
#
#     developmentstage                 constructiontype  \
# 531      Development                 NEW CONSTRUCTION
# 532      Development            DEMO/NEW CONSTRUCTION
# 533       In-Service                 NEW CONSTRUCTION
# 534       In-Service  BOTH REHAB AND NEW CONSTRUCTION
# 535       In-Service                 NEW CONSTRUCTION
#
#                                     siteaddress  sitecouncildistrict  site#  \
# 531   12667 SAN FERNANDO ROAD  Sylmar, CA 91342                    7      1
# 532      100 S GRAND AVE  Los Angeles, CA 90012                   14      1
# ...

# %%
# What is the highest siteunits?
df['siteunits'].max()
# Out:
# 438

# %%
df['siteunits'].min()
# Out:
# 0

# %%
df['jobs'].max()
# Out:
# 1165.0

# %%
df['jobs'].min()
# Out:
# 5.0

# %%
df['siteunits'].mean()
# Out:
# 53.115671641791046

# %%
df['jobs'].mean()
# Out:
# 186.85213032581453

# %%
len(df)
# Out:
# 536

# %%
df.sort_values('jobs', ascending=True).head()
# Out:
#             apn projectnumber                      name developmentstage  \
# 272  5141010004         20273  TIDES SENIORS APARTMENTS       In-Service
# 377  2654032001         50008        COLUMBUS PERMANENT       In-Service
# 478  5548018027     12-118880         MICHAEL'S VILLAGE       In-Service
# 224  4226006006     09-117283        HORIZON APARTMENTS       In-Service
# 105  5072036002         60064  SECOND AVENUE APARTMENTS       In-Service
#
#      constructiontype                                     siteaddress  \
# 272  NEW CONSTRUCTION       623 S RAMPART BLVD  Los Angeles, CA 90057
# 377             REHAB  8906 N COLUMBUS AVE 1-6  North Hills, CA 91343
# 478             REHAB         7160 W SUNSET BLVD  HOLLYWOOD, CA 90046
# 224             REHAB              15 E HORIZON AVE  VENICE, CA 90291
# 105             REHAB           1309 S 2ND AVE  Los Angeles, CA 90019
#
#      sitecouncildistrict  site#  sitecommunity  siteunits  projecttotalunits  \
# ...

# %%
df.sort_values('jobs', ascending=True).tail()
# Out:
#             apn projectnumber                                      name  \
# 517  5131008039     05-117217        LEXINGTON APARTMENTS A/B (SITE 13)
# 518  5135005008     06-117195  CONCORD APARTMENTS (GRP. A & B) (SITE 9)
# 524  6051023039     06-117222             WINDWARD APTS (A/B) (SITE 11)
# 527  5054020020     05-117217         LEXINGTON APARTMENTS A/B (SITE 6)
# 532  5149010949     18-124964               GRAND AVENUE PARCEL Q APTS.
#
#     developmentstage       constructiontype  \
# 517       In-Service                  REHAB
# 518       In-Service                  REHAB
# 524       In-Service                  REHAB
# 527       In-Service                  REHAB
# 532      Development  DEMO/NEW CONSTRUCTION
#
#                                       siteaddress  sitecouncildistrict  site#  \
# 517         1151 E 20TH ST  Los Angeles, CA 90011                    9     13
# 518  1350 S BONNIE BRAE ST  Los Angeles, CA 90006                    1      9
# ...

# %%
df['sitecommunity'].value_counts()
# Out:
# WESTLAKE              38
# WHOLESALE DISTRICT    27
# HOLLYWOOD             19
# CENTRAL               18
# KOREATOWN             17
#                       ..
# ELYSIAN VALLEY         1
# LOS FELIZ              1
# CRESTVIEW              1
# HANCOCK PARK           1
# EXPOSITION             1
# Name: sitecommunity, Length: 84, dtype: int64

# %%
df['constructiontype'].value_counts()
# Out:
# NEW CONSTRUCTION                   275
# REHAB                              133
# ACQUISITION + REHAB                 77
# BOTH REHAB AND NEW CONSTRUCTION     11
# ACQUISITION + NEW CONSTRUCTION       9
# DEMO/NEW CONSTRUCTION                5
# Name: constructiontype, dtype: int64

# %%
df.groupby(['sitecommunity'])['jobs'].mean()
# Out:
# sitecommunity
# ADAMS-NORMANDIE        99.000000
# ALSACE                       NaN
# ANGELINO HEIGHTS       63.000000
# ATWATER VILLAGE       264.333333
# BALDWIN HILLS         228.000000
#                          ...
# WESTLAKE              192.520000
# WHOLESALE DISTRICT    324.958333
# WILMINGTON            286.333333
# WILSHIRE CENTER       233.500000
# WINNETKA                     NaN
# Name: jobs, Length: 84, dtype: float64

# %%
df.groupby(['sitecommunity'])['siteunits'].mean()
# Out:
# sitecommunity
# ADAMS-NORMANDIE        7.000000
# ALSACE                 0.000000
# ANGELINO HEIGHTS      33.000000
# ATWATER VILLAGE       61.000000
# BALDWIN HILLS         86.000000
#                         ...
# WESTLAKE              62.184211
# WHOLESALE DISTRICT    87.037037
# WILMINGTON            89.666667
# WILSHIRE CENTER       47.750000
# WINNETKA              91.000000
# Name: siteunits, Length: 84, dtype: float64

# %%
df[df['sitecommunity'] == 'WESTLAKE']['jobs'].mean()
# Out:
# 192.52

# %%
df[df['constructiontype'] == 'REHAB']['jobs'].mean()
# Out:
# 79.47457627118644

# %%
df[df['sitecommunity'] == 'WESTLAKE']['siteunits'].mean()
# Out:
# 62.18421052631579

# %%
df[df['constructiontype'] == 'REHAB']['siteunits'].mean()
# Out:
# 32.037593984962406

# %%
df.groupby(['sitecommunity'])['siteunits'].agg(['min', 'max', 'count', 'mean']).reset_index()
# Out:
#          sitecommunity  min  max  count       mean
# 0      ADAMS-NORMANDIE    0   14      2   7.000000
# 1               ALSACE    0    0      1   0.000000
# 2     ANGELINO HEIGHTS   33   33      1  33.000000
# 3      ATWATER VILLAGE    0  108      5  61.000000
# 4        BALDWIN HILLS   69  103      2  86.000000
# ..                 ...  ...  ...    ...        ...
# 79            WESTLAKE    0  196     38  62.184211
# 80  WHOLESALE DISTRICT    0  438     27  87.037037
# 81          WILMINGTON   56  116      6  89.666667
# 82     WILSHIRE CENTER    0  100      8  47.750000
# 83            WINNETKA   91   91      1  91.000000
#
# [84 rows x 5 columns]

# %%
df.jobs.sum()
# Out:
# 74554.0

# %%
df.siteunits.sum()
# Out:
# 28470

# %%
df[df["sitecommunity"] == 'WHOLESALE DISTRICT']
# Out:
#             apn projectnumber  \
# 12   5147024024     18-125043
# 42   5148012009         60162
# 58   5147029002         20277
# 84   5148025008         30156
# 101  5131006005     14-121613
# 119  5148025024     17-124315
# 130  5147029048     18-124761
# 131  5148025025         10315
# 150  5174013905     14-121628
# 156  5148024026     17-124264
# 159  5148025009     17-124315
# 188  5148014013         70168
# 210  5148025017         50028
# 255  5164009012     15-121799
# 278  5148013004     19-125932
# 283  5148012005         70043
# 357  5147034016     15-121799
# 381  5414013900     13-119070
# 391  5174018900     19-125936
# 395  5147024024     18-125045
# 409  5174024020     10-117557
# 452  5148012022     11-117804
# 466  5163017900     10-117900
# 476  5148023020     11-117809
# 487  5148024007         60011
# 495  5148023031     15-122553
# 517  5131008039     05-117217
#
#                                                   name developmentstage  \
# ...

# %%
df[df["sitecouncildistrict"] == 14]
# Out:
#             apn projectnumber  \
# 12   5147024024     18-125043
# 28   5180001900     19-125934
# 42   5148012009         60162
# 58   5147029002         20277
# 64   5180002014     14-121648
# 76   5210008030         60083
# 82   5208019043     05-117217
# 84   5148025008         30156
# 110  5148019011     12-118778
# 119  5148025024     17-124315
# 121  5188005031     11-117205
# 124  5183023005     13-119072
# 129  5183001048     09-117211
# 130  5147029048     18-124761
# 131  5148025025         10315
# 148  5191012020     12-118877
# 150  5174013905     14-121628
# 154  5149037010     12-118785
# 156  5148024026     17-124264
# 159  5148025009     17-124315
# 161  5177018017         20289
# 166  5214001002     18-125042
# 168  5210024002     18-125506
# 188  5148014013         70168
# 189  5180002029     15-122536
# 191  5148011014     14-121647
# 210  5148025017         50028
# 214  5211007052         70026
# 219  5147011024     19-125940
# 238  5179019900     19-126520
# ...

# %%
district14 = df[df["sitecouncildistrict"] == 14]

# %%
district14.head()
# Out:
#            apn projectnumber  \
# 12  5147024024     18-125043
# 28  5180001900     19-125934
# 42  5148012009         60162
# 58  5147029002         20277
# 64  5180002014     14-121648
#
#                                                  name developmentstage  \
# 12  WEINGART TOWER A-134 (FKAWEINGART TOWER HHH PS...      Development
# 28                                         LA VERANDA      Development
# 42                            CHARLES COBB APARTMENTS       In-Service
# 58                                 NEW TERMINAL HOTEL       In-Service
# 64                CIELITO LINDO (1ST AND SOTO APTS I)       In-Service
#
#     constructiontype                                       siteaddress  \
# 12  NEW CONSTRUCTION                         555 S CROCKER ST CA 90013
# 28  NEW CONSTRUCTION  2420 E CESAR E CHAVEZ AVE  Los Angeles, CA 90033
# 42  NEW CONSTRUCTION         521 S SAN PEDRO ST  Los Angeles, CA 90013
# ...

# %%
district14.tail()
# Out:
#             apn projectnumber                                 name  \
# 487  5148024007         60011                         LYNDON HOTEL
# 495  5148023031     15-122553  649 LOFTS (AKA SIX FOUR NINE LOFTS)
# 530  5147007020         80058              DOWNTOWN WOMEN'S CENTER
# 532  5149010949     18-124964          GRAND AVENUE PARCEL Q APTS.
# 534  5183005010     09-117211              LAS MARGARITAS (SITE 2)
#
#     developmentstage                 constructiontype  \
# 487       In-Service                            REHAB
# 495       In-Service                 NEW CONSTRUCTION
# 530       In-Service                            REHAB
# 532      Development            DEMO/NEW CONSTRUCTION
# 534       In-Service  BOTH REHAB AND NEW CONSTRUCTION
#
#                                    siteaddress  sitecouncildistrict  site#  \
# 487        413 E 7TH ST  Los Angeles, CA 90014                   14      1
# 495       649 S WALL ST  LOS ANGELES, CA 90014                   14      1
# ...

# %%
district14.jobs.sum()
# Out:
# 13694.0

# %%
district14.siteunits.sum()
# Out:
# 4849

# %%
df[df["sitecouncildistrict"] == 9]
# Out:
#             apn projectnumber  \
# 4    5114014020     14-121652
# 7    5127029049     18-125459
# 9    5119011019     13-120909
# 10   5110025032     10-117556
# 13   5128015021     09-117212
# ..          ...           ...
# 505  6011003062     18-125039
# 512  5119001028         40072
# 517  5131008039     05-117217
# 519  5017027032     10-117605
# 533  5114014004     14-121652
#
#                                                 name developmentstage  \
# 4                            FLORENCE MILLS (SITE 5)       In-Service
# 7           LA PRENSA LIBRE- 9% (FKA WASHINGTON/ LA)      Development
# 9    ROBERTA STEPHENS VILLAS I & II (RECAP) (SITE 2)       In-Service
# 10                                SUNRISE APARTMENTS       In-Service
# 13                          THE CROSSING ON 29TH ST.       In-Service
# ..                                               ...              ...
# 505              RUTH TEAGUE HOMES (FKA 67TH & MAIN)      Development
# ...

# %%
district9 = df[df["sitecouncildistrict"] == 9]

# %%
district9.jobs.sum()
# Out:
# 8294.0

# %%
district9.siteunits.sum()
# Out:
# 2338

# %%
# Which site created the cheapest/most expensive units using LAHD funding/total leverage?

# %%
df.columns
# Out:
# Index(['apn', 'projectnumber', 'name', 'developmentstage', 'constructiontype',
#        'siteaddress', 'sitecouncildistrict', 'site#', 'sitecommunity',
#        'siteunits', 'projecttotalunits', 'housingtype', 'supportivehousing',
#        'datefunded', 'lahdfunded', 'leverage', 'taxexemptconduitbond', 'tdc',
#        'in-servicedate', 'developer', 'managementcompany', 'contactphone',
#        'photo', 'jobs', 'projectsummaryurl', 'contractnumbers', 'datestamp',
#        'sitelongitude', 'sitelatitude', 'gps_coordsonmap',
#        'constructiontype_new'],
#       dtype='object')

# %%
df["publicloanperunit"] = df["lahdfunded"]/df["siteunits"]

# %%
df.head()
# Out:
#           apn projectnumber                           name developmentstage  \
# 0  2629019017         40052                PALM VILLAGE SR       In-Service
# 1  6071001013     06-117222  WINDWARD APTS (A/B) (SITE 14)       In-Service
# 2  5545007097     11-117795                     THE GORDON       In-Service
# 3  5050011005     05-117193         LEEWARD APTS. (SITE 7)       In-Service
# 4  5114014020     14-121652        FLORENCE MILLS (SITE 5)       In-Service
#
#    constructiontype                                        siteaddress  \
# 0  NEW CONSTRUCTION    9034 N LAUREL CANYON BLVD  Sun Valley, CA 91352
# 1             REHAB          636 E 108TH ST 1-4  Los Angeles, CA 90059
# 2  NEW CONSTRUCTION              1553 N GORDON ST  HOLLYWOOD, CA 90028
# 3             REHAB            2809 S WEST BLVD  Los Angeles, CA 90016
# 4  NEW CONSTRUCTION  1037 E MARTIN LUTHER KING BLVD  LOS ANGELES, C...
#
#    sitecouncildistrict  site#       sitecommunity  siteunits  \
# ...

# %%
# Show me only districts 9 and 14 that have the cheapest site units.

# %%
df[(df["sitecouncildistrict"] == 9)|(df["sitecouncildistrict"] == 14)].sort_values("publicloanperunit", ascending = False)
# Out:
#             apn projectnumber                                          name  \
# 4    5114014020     14-121652                       FLORENCE MILLS (SITE 5)
# 65   5020027008         70172                 TWO WORLD APARTMENTS (SITE 6)
# 533  5114014004     14-121652                       FLORENCE MILLS (SITE 4)
# 501  6011003007     18-125039  RUTH TEAGUE HOMES (FKA 67TH & MAIN) (SITE 6)
# 414  5114014006     14-121652                       FLORENCE MILLS (SITE 3)
# ..          ...           ...                                           ...
# 102  6022009004     05-117217             LEXINGTON APARTMENTS A/B (SITE 7)
# 114  5119002017     05-117217            LEXINGTON APARTMENTS A/B (SITE 12)
# 287  5119005012     05-117217            LEXINGTON APARTMENTS A/B (SITE 14)
# 301  6030011028     05-117193                       LEEWARD APTS. (SITE 14)
# 517  5131008039     05-117217            LEXINGTON APARTMENTS A/B (SITE 13)
#
#     developmentstage  constructiontype  \
# ...

# %%
# Why are these projects with no site units getting so much funding?

# %%
# !pwd
# Out:
# /Users/gabrielalevy/github/stiles_usc/students/gllevy
