# %% [markdown]
# # Class mapping exercise
# Choose one of the map ideas below, processed the data with GeoPandas and export the data to QGIS for presentation. *Hint: You might need to change data types using the `dtype` argument when importing files so that you can merge with FIPS and ZIP codes effectively.*

# %% [markdown]
# #### Load python tools

# %%
# %load_ext lab_black

# %%
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000

# %% [markdown]
# ### Election map
# #### What percentage of vote did Biden/Trump receive in California counties?

# %%
# Values: https://raw.githubusercontent.com/stiles/notebooks/master/elections/data/ca_counties_election_results_2020.csv
# Geo: https://raw.githubusercontent.com/stiles/usc/main/data/geo/counties_simple.geojson

# %% [markdown]
# #### Read election results

# %%
elections_df = pd.read_csv(
    "https://raw.githubusercontent.com/stiles/notebooks/master/elections/data/ca_counties_election_results_2020.csv"
)

# %%
elections_df.head()
# Out:
#    state_name  county_fips county_name  votes_gop  votes_dem  total_votes  \
# 0  California            1     Alameda     136309     617659       769864
# 1  California            3      Alpine        244        476          741
# 2  California            5      Amador      13585       8153        22302
# 3  California            7       Butte      48730      50426       102042
# 4  California            9   Calaveras      16518      10046        27164
#
#      diff   per_gop   per_dem  per_point_diff winner
# 0 -481350  0.177056  0.802296        0.625240  Biden
# 1    -232  0.329285  0.642375        0.313090  Biden
# 2    5432  0.609138  0.365573        0.243566  Trump
# 3   -1696  0.477548  0.494169        0.016621  Biden
# 4    6472  0.608084  0.369828        0.238257  Trump

# %% [markdown]
# #### Read county boundaries

# %% [markdown]
# #### Merge the two

# %% [markdown]
# ---

# %% [markdown]
# ### Vehicle map
# ##### What's the Tesla ownership rate by LA ZIP Codes?

# %%
# Values: https://raw.githubusercontent.com/stiles/notebooks/master/california-fuel-vehicles/output/tesla_zips_slim.csv
# Geo: https://raw.githubusercontent.com/stiles/notebooks/master/zips/data/processed/ca_zips_simple.geojson.json

# %% [markdown]
# #### Read Tesla data

# %%
tesla_df = pd.read_csv(
    "https://raw.githubusercontent.com/stiles/notebooks/master/california-fuel-vehicles/output/tesla_zips_slim.csv",
    dtype={"zip": str},
)

# %%
tesla_df.head()
# Out:
#      zip         name  teslas  all_vehicles  tesla_rate_1k  avg_house_income  \
# 0  90004  Los Angeles     200         22734           8.80             65893
# 1  90005  Los Angeles      58         12518           4.63             53191
# 2  90006  Los Angeles      26         17324           1.50             42242
# 3  90007  Los Angeles      27         10707           2.52             38564
# 4  90008  Los Angeles      54         12611           4.28             56286
#
#    avg_net_worth
# 0         232653
# 1         105569
# 2          39289
# 3          39966
# 4         284531

# %% [markdown]
# #### Read ZIP Codes geo file

# %% [markdown]
# #### Merge the two

# %% [markdown]
# #### Export merged geo file

# %% [markdown]
# ---

# %% [markdown]
# ### Population map
# ##### How's the white population distributed in LA by neighborhood?

# %%
# Values:https://raw.githubusercontent.com/stiles/usc/main/data/processed/la_neighborhood_demographics.csv
# Geo: https://raw.githubusercontent.com/stiles/usc/main/data/geo/la-neighborhoods.geojson

# %% [markdown]
# #### Read race/ethnicity data

# %%
whites_la_df = pd.read_csv(
    "https://raw.githubusercontent.com/stiles/usc/main/data/processed/la_neighborhood_demographics.csv"
)

# %%
whites_la_df.head()
# Out:
#               name  total_population  white_alone  black_alone  \
# 0            Acton           13533.0       3030.0         43.0
# 1  Adams-Normandie           37987.0       1455.0       3601.0
# 2     Agoura Hills           27220.0       9337.0        415.0
# 3       Agua Dulce           17982.0       3431.0         84.0
# 4         Alhambra          105896.0       3511.0        810.0
#
#    american_indian_and_alaska_native  asian_alone  \
# 0                                9.0        122.0
# 1                                6.0       1622.0
# 2                                0.0       1055.0
# 3                               29.0        176.0
# 4                              109.0      19403.0
#
#    native_hawaiian_and_pacific_islander  other_alone  two_or_more_races  \
# 0                                   0.0          0.0               64.0
# 1                                  62.0         32.0              273.0
# 2                                   0.0         32.0              418.0
# 3                                   2.0          4.0              131.0
# 4                                 191.0        149.0              773.0
#
#    latino_alone  asians_all  other_all  white_percent  black_percent  \
# 0        1019.0       123.0       73.0          22.39           0.32
# 1       11751.0      1683.0      311.0           3.83           9.48
# 2        1548.0      1055.0      451.0          34.30           1.52
# 3        1025.0       179.0      164.0          19.08           0.47
# 4       15428.0     19594.0     1031.0           3.32           0.76
#
#    american_indian_percent  asian_percent  native_hawaiian_percent  \
# 0                     0.07           0.90                     0.00
# 1                     0.02           4.27                     0.16
# 2                     0.00           3.88                     0.00
# 3                     0.16           0.98                     0.01
# 4                     0.10          18.32                     0.18
#
#    other_percent  two_or_more_races_percent  latino_percent  \
# 0           0.00                       0.47            7.53
# 1           0.08                       0.72           30.93
# 2           0.12                       1.54            5.69
# 3           0.02                       0.73            5.70
# 4           0.14                       0.73           14.57
#
#    asians_all_percent  other_all_percent  nonwhite_percent  majority_nonwhite  \
# 0                0.91               0.54             77.61               True
# 1                4.43               0.82             96.17               True
# 2                3.88               1.66             65.70               True
# 3                0.99               0.91             80.92               True
# 4               18.50               0.97             96.68               True
#
#    majority_white  majority_black  majority_american_indian_and_alaska_native  \
# 0           False           False                                       False
# 1           False           False                                       False
# 2           False           False                                       False
# 3           False           False                                       False
# 4           False           False                                       False
#
#    majority_asian  majority_native_hawaiian  majority_other  \
# 0           False                     False           False
# 1           False                     False           False
# 2           False                     False           False
# 3           False                     False           False
# 4           False                     False           False
#
#    majority_two_or_more_races  majority_latino  median_householdincome  \
# 0                       False            False            99453.506605
# 1                       False            False            37419.270130
# 2                       False            False           121211.788628
# 3                       False            False           108312.326136
# 4                       False            False            61884.537960
#
#    total_occupied_housing_units  owner_occupied  renter_occupied  \
# 0                   1474.265218     1329.164851       145.100367
# 1                   5437.575802     1123.870291      4313.705512
# 2                   4675.116219     3311.101230      1364.014989
# 3                   1490.569409     1408.056410        82.512999
# 4                  13840.151455     5937.368580      7902.782874
#
#    owner_percent  renter_percent  majority_owner  majority_renter  \
# 0       0.901578        0.098422            True            False
# 1       0.206686        0.793314           False             True
# 2       0.708239        0.291761            True            False
# 3       0.944643        0.055357            True            False
# 4       0.428996        0.571004           False             True
#
#    majorityhigherthanmedianincomeLA
# 0                              True
# 1                             False
# 2                              True
# 3                              True
# 4                             False

# %% [markdown]
# #### Read LA neighborhoods geo file

# %% [markdown]
# #### Merge the two

# %% [markdown]
# #### Export merged geo file
