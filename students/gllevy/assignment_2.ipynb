# %%
import pandas as pd

# %%
url = "https://data.lacity.org/Housing-and-Real-Estate/LAHD-Affordable-Housing-Projects-List-2003-to-Pres/psx4-6drg"

# %%
housing_df = pd.read_csv("Affordable_Housing.csv")

# %%
housing_df.columns = housing_df.columns.str.lower().str.replace(" ", "", regex=False)

# %%
housing_df["constructiontype_new"] = (
    housing_df["constructiontype"].str.lower().str.replace(" ", "", regex=False)
)

# %%
housing_df.head()
# Out:
#           apn projectnumber                           name developmentstage  \
# 0  2629019017         40052                PALM VILLAGE SR       In-Service
# 1  6071001013     06-117222  WINDWARD APTS (A/B) (SITE 14)       In-Service
# 2  5545007097     11-117795                     THE GORDON       In-Service
# 3  5050011005     05-117193         LEEWARD APTS. (SITE 7)       In-Service
# 4  5114014020     14-121652        FLORENCE MILLS (SITE 5)       In-Service
#
#    constructiontype                                        siteaddress  \
# 0  NEW CONSTRUCTION    9034 N LAUREL CANYON BLVD  Sun Valley, CA 91352
# 1             REHAB          636 E 108TH ST 1-4  Los Angeles, CA 90059
# 2  NEW CONSTRUCTION              1553 N GORDON ST  HOLLYWOOD, CA 90028
# 3             REHAB            2809 S WEST BLVD  Los Angeles, CA 90016
# 4  NEW CONSTRUCTION  1037 E MARTIN LUTHER KING BLVD  LOS ANGELES, C...
#
#    sitecouncildistrict  site#       sitecommunity  siteunits  ...  \
# ...

# %%
housing_df.tail()
# Out:
#             apn projectnumber                                 name  \
# 531  2604028031     19-125927  SILVA CROSSING (FKA LINK AT SYLMAR)
# 532  5149010949     18-124964          GRAND AVENUE PARCEL Q APTS.
# 533  5114014004     14-121652              FLORENCE MILLS (SITE 4)
# 534  5183005010     09-117211              LAS MARGARITAS (SITE 2)
# 535  5153006024         50035                          UNION POINT
#
#     developmentstage                 constructiontype  \
# 531      Development                 NEW CONSTRUCTION
# 532      Development            DEMO/NEW CONSTRUCTION
# 533       In-Service                 NEW CONSTRUCTION
# 534       In-Service  BOTH REHAB AND NEW CONSTRUCTION
# 535       In-Service                 NEW CONSTRUCTION
#
#                                     siteaddress  sitecouncildistrict  site#  \
# 531   12667 SAN FERNANDO ROAD  Sylmar, CA 91342                    7      1
# 532      100 S GRAND AVE  Los Angeles, CA 90012                   14      1
# ...

# %%
len(housing_df)
# Out:
# 536

# %%
housing_df.siteunits.sum()
# Out:
# 28470

# %%
housing_df.jobs.sum()
# Out:
# 74554.0

# %%
housing_df[housing_df["constructiontype_new"] == "newconstruction"]
# Out:
#             apn projectnumber                                            name  \
# 0    2629019017         40052                                 PALM VILLAGE SR
# 2    5545007097     11-117795                                      THE GORDON
# 4    5114014020     14-121652                         FLORENCE MILLS (SITE 5)
# 5    4012018025         60013                       MORGAN PLACE SENIOR APTS.
# 7    5127029049     18-125459        LA PRENSA LIBRE- 9% (FKA WASHINGTON/ LA)
# ..          ...           ...                                             ...
# 526  5049034009     14-121639  YBARRA VILLAGE (FKA NEW DIRECTIONS WEST ADAMS)
# 529  6132026030     18-125515   THE DAHLIA (FKA SOUTH MAIN STREET APARTMENTS)
# 531  2604028031     19-125927             SILVA CROSSING (FKA LINK AT SYLMAR)
# 533  5114014004     14-121652                         FLORENCE MILLS (SITE 4)
# 535  5153006024         50035                                     UNION POINT
#
# ...

# %%
housing_df[housing_df["jobs"] < 100.0]
# Out:
#             apn projectnumber  \
# 0    2629019017         40052
# 2    5545007097     11-117795
# 6    5153030026         50036
# 8    5037025018     14-121612
# 9    5119011019     13-120909
# ..          ...           ...
# 510  6117003018         80002
# 520  2656018034     09-104740
# 521  5545014044     13-119154
# 528  5072037019         80053
# 535  5153006024         50035
#
#                                                  name developmentstage  \
# 0                                     PALM VILLAGE SR       In-Service
# 2                                          THE GORDON       In-Service
# 6                                      WITMER HEIGHTS       In-Service
# 8                                           KING 1101       In-Service
# 9     ROBERTA STEPHENS VILLAS I & II (RECAP) (SITE 2)       In-Service
# ..                                                ...              ...
# 510                                     MY TOWN HOMES       In-Service
# ...

# %%
housing_df.groupby(["sitecommunity"]).agg({"projectnumber": "size"}).reset_index()
# Out:
#          sitecommunity  projectnumber
# 0      ADAMS-NORMANDIE              2
# 1               ALSACE              1
# 2     ANGELINO HEIGHTS              1
# 3      ATWATER VILLAGE              5
# 4        BALDWIN HILLS              2
# ..                 ...            ...
# 79            WESTLAKE             38
# 80  WHOLESALE DISTRICT             27
# 81          WILMINGTON              6
# 82     WILSHIRE CENTER              8
# 83            WINNETKA              1
#
# [84 rows x 2 columns]

# %%
housing_df.groupby(["sitecommunity"]).agg({"jobs": "mean"}).round(0).reset_index()
# Out:
#          sitecommunity   jobs
# 0      ADAMS-NORMANDIE   99.0
# 1               ALSACE    NaN
# 2     ANGELINO HEIGHTS   63.0
# 3      ATWATER VILLAGE  264.0
# 4        BALDWIN HILLS  228.0
# ..                 ...    ...
# 79            WESTLAKE  193.0
# 80  WHOLESALE DISTRICT  325.0
# 81          WILMINGTON  286.0
# 82     WILSHIRE CENTER  234.0
# 83            WINNETKA    NaN
#
# [84 rows x 2 columns]

# %%
housing_df.groupby(["sitecommunity"]).agg({"siteunits": "mean"}).round(0).reset_index()
# Out:
#          sitecommunity  siteunits
# 0      ADAMS-NORMANDIE        7.0
# 1               ALSACE        0.0
# 2     ANGELINO HEIGHTS       33.0
# 3      ATWATER VILLAGE       61.0
# 4        BALDWIN HILLS       86.0
# ..                 ...        ...
# 79            WESTLAKE       62.0
# 80  WHOLESALE DISTRICT       87.0
# 81          WILMINGTON       90.0
# 82     WILSHIRE CENTER       48.0
# 83            WINNETKA       91.0
#
# [84 rows x 2 columns]
