# %% [markdown]
# # How often is 'x' mentioned on Twitter?
# ##### *Counts pulled with the Twarc library. [Check it out](https://twarc-project.readthedocs.io/en/latest/twarc2_en_us/)*.

# %% [markdown]
# #### Load Python tools

# %%
# %load_ext lab_black

# %%
import pandas as pd
import altair as alt

# %%
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000

# %% [markdown]
# ---

# %% [markdown]
# #### Read data

# %%
mentioned = "Elon Musk"
src = pd.read_csv(
    "../../data/raw/twitter_mentions/elonmusk_mentions_daily_full_name.csv",
    parse_dates=["start", "end"],
).sort_values("start", ascending=False)

# %% [markdown]
# #### First five rows

# %%
mentioned = "Elon Musk"

src = pd.read_csv(
    "../../data/raw/twitter_mentions/elonmusk_mentions_daily_full_name.csv",
    parse_dates=["start", "end"],
).sort_values("start", ascending=False)

# %% [markdown]
# #### Process dates

# %%
src["year"] = pd.to_datetime(src["start"]).dt.strftime("%Y")
src["month_year"] = pd.to_datetime(src["start"]).dt.strftime("%Y-%m")
src["date"] = pd.to_datetime(src["start"]).dt.strftime("%Y-%m-%d")

# %% [markdown]
# #### Slim down and re-order the dataframe

# %%
src.head()
# Out:
#                        start                       end  day_count  year  \
# 30 2022-04-14 00:00:00+00:00 2022-04-14 20:09:09+00:00     694825  2022
# 29 2022-04-13 00:00:00+00:00 2022-04-14 00:00:00+00:00      81318  2022
# 28 2022-04-12 00:00:00+00:00 2022-04-13 00:00:00+00:00      83130  2022
# 27 2022-04-11 00:00:00+00:00 2022-04-12 00:00:00+00:00     182429  2022
# 26 2022-04-10 00:00:00+00:00 2022-04-11 00:00:00+00:00      95818  2022
#
#    month_year        date
# 30    2022-04  2022-04-14
# 29    2022-04  2022-04-13
# 28    2022-04  2022-04-12
# 27    2022-04  2022-04-11
# 26    2022-04  2022-04-10

# %%
df = src[["year", "month_year", "date", "day_count"]].copy()

# %% [markdown]
# #### When was the first mention?

# %%
df[df["day_count"] > 0].tail(1)
# Out:
#       year month_year        date  day_count
# 5501  2007    2007-03  2007-03-21          4

# %% [markdown]
# #### Define that as a variable

# %%
first = df[df["day_count"] > 0]["month_year"].tail(1).iloc[0]

# %%
# .iloc says you only want the first column of data

# %%
first
# Out:
# '2007-03'

# %% [markdown]
# #### How many total mentions?

# %%
df.day_count.sum()
# Out:
# 33466375

# %% [markdown]
# #### Average mentions?

# %%
df.day_count.mean()
# Out:
# 5702.227807122167

# %% [markdown]
# #### Make a new dataframe starting from first mention

# %%
df_complete = df[df["date"] > first]

# %% [markdown]
# #### Which day was mentioned the most?

# %%
df_complete[df_complete["day_count"] == df_complete["day_count"].max()]
# Out:
#     year month_year        date  day_count
# 30  2022    2022-04  2022-04-14     694825

# %% [markdown]
# #### Chart it

# %%
alt.Chart(df_complete.head(365 * 2)).mark_area(color="red").encode(
    x="date:T", y="day_count:Q",
).properties(width=900)
# Out:
# alt.Chart(...)

# %% [markdown]
# ---

# %% [markdown]
# ## Aggregate

# %% [markdown]
# #### Groupby month/year

# %%
df_complete.groupby(["month_year"]).agg({"day_count": sum}).sort_values(
    "month_year"
).reset_index()
# Out:
#     month_year  day_count
# 0      2007-03          4
# 1      2007-04          0
# 2      2007-05          4
# 3      2007-06          0
# 4      2007-07          0
# 5      2007-08          2
# 6      2007-09          2
# 7      2007-10          3
# 8      2007-11          0
# 9      2007-12          4
# 10     2008-01          1
# 11     2008-02         15
# 12     2008-03          6
# 13     2008-04          8
# 14     2008-05         24
# 15     2008-06         20
# 16     2008-07         10
# 17     2008-08         62
# 18     2008-09         78
# 19     2008-10         77
# 20     2008-11        134
# 21     2008-12         38
# 22     2009-01         55
# 23     2009-02         44
# 24     2009-03        110
# 25     2009-04        706
# 26     2009-05        486
# 27     2009-06        989
# 28     2009-07        241
# 29     2009-08        188
# 30     2009-09        249
# 31     2009-10         66
# 32     2009-11        124
# 33     2009-12         54
# 34     2010-01        259
# 35     2010-02        928
# 36     2010-03        215
# 37     2010-04        392
# 38     2010-05       1822
# 39     2010-06       3433
# 40     2010-07       2850
# 41     2010-08       1683
# 42     2010-09        341
# 43     2010-10        829
# 44     2010-11       1006
# 45     2010-12       1860
# 46     2011-01        652
# 47     2011-02        309
# 48     2011-03       1090
# 49     2011-04       3769
# 50     2011-05       1347
# 51     2011-06        364
# 52     2011-07        551
# 53     2011-08       2895
# 54     2011-09       3355
# 55     2011-10       2605
# 56     2011-11       1073
# 57     2011-12       1391
# 58     2012-01       1248
# 59     2012-02       2841
# 60     2012-03       3573
# 61     2012-04       8462
# 62     2012-05      12265
# 63     2012-06       5758
# 64     2012-07       5041
# 65     2012-08       6611
# 66     2012-09       7386
# 67     2012-10       5936
# 68     2012-11      17439
# 69     2012-12       5521
# 70     2013-01       6487
# 71     2013-02      23805
# 72     2013-03      27605
# 73     2013-04      11902
# 74     2013-05      29745
# 75     2013-06      10509
# 76     2013-07      23662
# 77     2013-08      87226
# 78     2013-09      27602
# 79     2013-10      28251
# 80     2013-11      21548
# 81     2013-12      13389
# 82     2014-01       9345
# 83     2014-02      22195
# 84     2014-03      30268
# 85     2014-04      21106
# 86     2014-05      31311
# 87     2014-06      62891
# 88     2014-07      33753
# 89     2014-08      32995
# 90     2014-09      22615
# 91     2014-10      72805
# 92     2014-11      40911
# 93     2014-12      32443
# 94     2015-01     118259
# 95     2015-02      43904
# 96     2015-03      62703
# 97     2015-04      51872
# 98     2015-05     124737
# 99     2015-06      65414
# 100    2015-07      65350
# 101    2015-08      58205
# 102    2015-09      83363
# 103    2015-10     101588
# 104    2015-11      52751
# 105    2015-12     110230
# 106    2016-01      83694
# 107    2016-02      68668
# 108    2016-03      42992
# 109    2016-04     114910
# 110    2016-05      83860
# 111    2016-06     188633
# 112    2016-07     131931
# 113    2016-08      88142
# 114    2016-09     215369
# 115    2016-10     142948
# 116    2016-11     128445
# 117    2016-12      90214
# 118    2017-01     106701
# 119    2017-02     165354
# 120    2017-03     178354
# 121    2017-04     155425
# 122    2017-05     161440
# 123    2017-06     211956
# 124    2017-07     233856
# 125    2017-08     205230
# 126    2017-09     176549
# 127    2017-10     188115
# 128    2017-11     204643
# 129    2017-12     197117
# 130    2018-01     136204
# 131    2018-02     504855
# 132    2018-03     258165
# 133    2018-04     166697
# 134    2018-05     406458
# 135    2018-06     244331
# 136    2018-07     731463
# 137    2018-08     422373
# 138    2018-09     484183
# 139    2018-10     233781
# 140    2018-11     173154
# 141    2018-12     205061
# 142    2019-01     132505
# 143    2019-02     167166
# 144    2019-03     154543
# 145    2019-04     222831
# 146    2019-05     141374
# 147    2019-06     213010
# 148    2019-07     169351
# 149    2019-08     134518
# 150    2019-09     128460
# 151    2019-10     148812
# 152    2019-11     332641
# 153    2019-12     194828
# 154    2020-01     253561
# 155    2020-02     139292
# 156    2020-03     239147
# 157    2020-04     350551
# 158    2020-05    1513290
# 159    2020-06     234713
# 160    2020-07    1081234
# 161    2020-08     476292
# 162    2020-09     319618
# 163    2020-10     222102
# 164    2020-11     304413
# 165    2020-12     412030
# 166    2021-01    1099349
# 167    2021-02     959493
# 168    2021-03     676464
# 169    2021-04     668999
# 170    2021-05    1468003
# 171    2021-06     846389
# 172    2021-07     650093
# 173    2021-08     560458
# 174    2021-09     469916
# 175    2021-10     826472
# 176    2021-11    1116963
# 177    2021-12    1480705
# 178    2022-01     952070
# 179    2022-02    1111814
# 180    2022-03    1246998
# 181    2022-04    2330987

# %% [markdown]
# #### Which month-year was max?

# %% [markdown]
# ---

# %% [markdown]
# #### Exports

# %%
df_complete.to_csv(f"data/twitter_mentions_{mentioned}.csv", index=False)
